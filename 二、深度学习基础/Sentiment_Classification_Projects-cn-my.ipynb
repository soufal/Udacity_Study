# %% [markdown]
# # 情感分类 & 建立神经网络时，应如何“搭建问题框架”
# 讲师：Andrew Trask
#
# - **推特**: @iamtrask
# - **博客**: http://iamtrask.github.io
#
# ### 你应该掌握的背景知识
#
# - 神经网络、前向传播、反向传播
# - 随机梯度下降
# - 均方误差
# - 训练集/测试集的切分
#
# ### 如有需要，请
# - 重看优达学城以前的课程
# - 充分利用课程的推荐阅读材料 - [《深度学习详解》](https://www.manning.com/books/grokking-deep-learning) (请进入课室查看优惠码)
# - @iamtrask 给我发推特
#
#
# ### 教学大纲：
#
# - 简介： “搭建问题框架”的重要性（本课）
#
# - [管护数据集](#lesson_1)
# - [提出“预测理论”](#lesson_2)
# - [**项目 1**：快速验证理论](#project_1)
#
#
# - [将文本转换成数字](#lesson_3)
# - [**项目 2**：创建输入/输出数据](#project_2)
#
#
# - 融会贯通，创建神经网络 (仅视频 - 无 notebook 内容)
# - [**项目 3**：创建神经网络](#project_3)
#
#
# - [理解神经噪声](#lesson_4)
# - [**项目 4**：通过降噪来提高网络学习速度](#project_4)
#
#
# - [分析网络的不足之处](#lesson_5)
# - [**项目 5**：提高网络训练和运行的速度](#project_5)
#
#
# - [进一步降噪](#lesson_6)
# - [**项目 6**：有策略地删减词汇，进行降噪](#project_6)
#
#
# - [分析：权重怎么了？](#lesson_7)
#
# # 课程：管护数据集<a id='lesson_1'></a>
# 从此处开始到项目 1 为止的代码框包含了 Andrew 在迷你项目 1 教学视频之前用过的代码，因此你无需手动输入，即可跟着视频运行代码。

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

# %%
g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **注:** 对于正在使用的 `reviews.txt` 中的数据，我们已进行了一些预处理，现在数据只包含小写字符，但如果我们现在使用的是原始数据，因为不知道数据是否全为小写，所以此时应添加一步操作，进行大小写转换。处理同一个单词的不同形态时，如 `The`、 `the` 和 `THE`，也要进行同样的转换。

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # 课程: 提出预测理论<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # 项目 1: 快速验证理论<a id='project_1'></a>
#
# 实现这些项目的方法有很多，但为了让你的代码接近 Andrew 在解决方案里使用的代码，我们在这个 notebook 里给出了一些提示和代码的开头部分。
#
# 请在本练习中善加利用 [计数器](https://docs.python.org/2/library/collections.html#collections.Counter) 类和 [numpy](https://docs.scipy.org/doc/numpy/reference/) 库。

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# 我们要创建三个 `计数器` 对象，其中一个为正面评价的单词计数，一个为负面评价的单词计数，还有一个为所有单词计数。

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **待办：** 遍历所有评价，每遇到一个出现在正面评价里的单词，就为该单词的正面评价计数器和总计数器增量；同理，每遇到一个出现在负面评价里的单词，就为该单词的负面评价计数器和总计数器增量。
#
# **注:** 在这些项目中，请用 `split(' ')` 来将一段文本（比如一段评价）分割成独立的单词，如果你用的是 `split()`，那结果会和视频以及解决方案里的有所出入。

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
#方法一
for i in range(len(reviews)):
    i_list = reviews[i].split(' ')
    for j in i_list:
        if labels[i] == 'POSITIVE':
            positive_counts[j] += 1
        else:
            negative_counts[j] += 1
        total_counts[j] += 1

# %%
#方法二
for i in range(len(reviews)):
    if (labels[i] == 'POSITIVE'):
        for word in reviews[i].split(' '):
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in reviews[i].split(' '):
            negative_counts[word] += 1
            total_counts[word] += 1

# %% [markdown]
# 运行下方两个代码框，分别列出出现在正面评价和负面评价中的单词，并按出现频率由高到低排序。

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common(10)
# Out:
# [('', 550468),
#  ('the', 173324),
#  ('.', 159654),
#  ('and', 89722),
#  ('a', 83688),
#  ('of', 76855),
#  ('to', 66746),
#  ('is', 57245),
#  ('in', 50215),
#  ('br', 49235)]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common(10)
# Out:
# [('', 561462),
#  ('.', 167538),
#  ('the', 163389),
#  ('a', 79321),
#  ('and', 74385),
#  ('of', 69009),
#  ('to', 68974),
#  ('br', 52637),
#  ('is', 50083),
#  ('it', 48327)]

# %% [markdown]
# 你可以发现，如 “the” 等常见单词在正面评价和负面评价中出现的频率都很高，因此，你要找的其实不是正面评价或负面评价中最常见的单词，而是在正面评价里的出现频率比在负面评价里的高的单词，以及在负面评价里的出现频率比在正面评价里的高的单词，为此，你需要计算单词在正面评价与负面评价中出现的次数的 **比值**。
#
# **待办：** 查看所有你见过的单词，计算各单词在正面评价和负面评价中出现的次数的比值，并将这些比值存入 `pos_neg_ratios`。
# >提示：计算给定单词的正面评价/负面评价比，可使用 `positive_counts[word] / float(negative_counts[word]+1)`。注意，分母要 `+1`——这样如果遇到只在正面评价中出现的单词，分母不会变为 0。

# %% [markdown]
# **通过使用单词的评价比，可以有效的排除掉例如‘the’这样不能够决定情绪分类的常用单词。 **
#
# > * 当单词的正面评价/负面评价比等于1时：说明该词在正面和负面中出现的次数差不多，可以认为是常用日常常用词，不能够决定情绪分类。
# > * 当单词的正面评价/负面评价比大于1时：说明该词在正面评价中出现的次数比负面出现的次数多，可以认为是能决定正面情绪的词。

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times 
for i in range(len(reviews)):
    i_list = reviews[i].split(' ')
    for word in i_list:
        pos_neg_ratios[word] = positive_counts[word] / float(negative_counts[word]+1)

# %% [markdown]
# 查看若干单词的比值计算结果：

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0
# Pos-to-neg ratio for 'amazing' = 0
# Pos-to-neg ratio for 'terrible' = 0

# %% [markdown]
# 仔细观察刚才算出的比值，我们可以发现：
#
# * 那些你觉得在正面评价里会更常见的单词——如 "amazing" ——比值大于 1。单词在正面评价中出现得越频繁，其正面评价/负面评价比就越大于 1。
# * 那些你觉得在负面评价里会更常见的单词——如 "terrible" ——比值小于 1。单词在负面评价里出现得越频繁，其正面评价/负面评价比就越接近 0。
# * 中性词不含任何感情色彩，毕竟它们在各类评论中都有出现——如 "the" —— 比值非常接近 1。 一个完全中性的词，也即在正面评价和负面评价中出现次数完全相同的词，比值会无限接近于 1。虽然因为上文的建议，分母进行了 `+1` 处理，使得单词稍稍偏向负面，但因为这个偏置很小，而我们稍后会忽略太接近于中性的词，所以影响不大。
#
# 好了，虽然比值能告诉我们哪个单词在正面评价/负面评价中出现得更频繁，但要处理我们算出的这些具体数值还是有点麻烦。褒义色彩十分浓厚的词，如 "amazing"，其比值大于4，而贬义色彩十分浓厚的词，如 "terrible"，其比值则在 0.18 左右，要比较这些数值并不容易，原因如下：
#
# * 现在我们视 1 为中性，但因为褒义色彩十分浓厚的词的正面评价/负面评价比的绝对值比贬义色彩十分浓厚的词的比的绝对值大，所以我们无法直接比较这两者，也就无从确定这两个单词所包含的褒义/贬义程度是否相同，因此，我们应以中性值为所有数值的中心，这样一来，就可以用单词的正面评价/负面评价比与中性值之差的绝对值来衡量单词蕴含了多少感情色彩（褒义/贬义）了。
# * 在比较绝对值时，以 0 为中心要比以 1 为中心容易。
#
# 要解决上述问题，我们要对所有比值进行对数变换，从而得出新值。
#
# **待办：** 遍历你计算出来的所有比值，将其转化为对数。(也就是说，使用 `np.log(ratio)`)
#
# 到最后，褒义色彩极为浓厚的单词的正面评价/负面评价比会与贬义色彩极为浓厚的单词的比的大小相似，但符号相反。

# %%
#实例解决方法
pos_neg_ratios = Counter()

#计算正面评价和负面评价比值
for term, cnt in list(total_counts.most_common()):
    #筛选出对情绪预测有真正作用的词。
    if(cnt > 100):
        pos_neg_ratio = positive_counts[term] / float(negative_counts[term] + 10)
        pos_neg_ratios[term] = pos_neg_ratio

#将比值转换为对数
for word, ratio in pos_neg_ratios.most_common():
    if(ratio > 1):
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = -np.log(ratio + 0.01)

# %%
# TODO: Convert ratios to logs、
for word in pos_neg_ratios:
    pos_neg_ratios[word] = np.log(pos_neg_ratios[word])
# pos_neg_ratios
# Out:
# c:\users\wyf35\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# 查看之前那些单词的新比值计算结果：

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = -2.8307669205822776
# Pos-to-neg ratio for 'amazing' = 0.30625861467911936
# Pos-to-neg ratio for 'terrible' = 0.519021639820512

# %% [markdown]
# 如果一切顺利，现在中性词的比值应该接近于 0。此时，"the" 接近 0 但仍是个十分小的正数，所以这个单词可能在正面评价中出现的次数比在负面评价中的多，但我们来看 "amazing"，其比值大于 `1`，意味着这是个明确的褒义词，而 "terrible" 的比值与其相似，但符号不同，也就是小于 `-1`，由此我们可以清楚地得知这两个单词具有特定浓度且相反的感情色彩。
#
# 现在，运行下方代码框，观察更多比值。
#
# 第一个代码框会列出所有单词，并按单词与正面评价的相关性排序。（你的 notebook 很可能会对输出进行删减，所以你不会真的看到列表里的*所有*单词。）
#
# 第二个代码框会列出 30 个与负面评价关系最紧密的单词——首先代码会反转第一张列表的顺序，然后查找前 30 个单词。（如果想让第二个代码框列出所有单词并按单词与负面评价的相关性排序，你可以写 `reversed(pos_neg_ratios.most_common())`。）
#
# 你接下来看到的数值会和我们之前看到的类似——中性词的比值接近 `0`；单词在正面评价里出现得越频繁，其比值就越接近甚至大于 `1`；单词在负面评价里出现得越频繁，其比值就越接近甚至小于 `-1`。这就是我们用对数而非原始比值的原因所在。

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('boll', 4.102218618653007),
#  ('uwe', 3.962842253824359),
#  ('seagal', 3.361264671326784),
#  ('unwatchable', 3.0922821595296623),
#  ('stinker', 3.0568199655338293),
#  ('incoherent', 2.8193384163933115),
#  ('mst', 2.818025399614709),
#  ('unfunny', 2.5851520647790562),
#  ('waste', 2.496553155174324),
#  ('blah', 2.4899191916115444),
#  ('horrid', 2.4427317247372877),
#  ('edie', 2.388762789235098),
#  ('paulie', 2.372789351667294),
#  ('pointless', 2.3622233593137767),
#  ('atrocious', 2.3622233593137767),
#  ('prom', 2.333492630457122),
#  ('drivel', 2.315572288520857),
#  ('redeeming', 2.2935352574741277),
#  ('lousy', 2.2515299221937615),
#  ('victoria', 2.211017899468555),
#  ('worst', 2.196381559281837),
#  ('laughable', 2.1935258423414696),
#  ('wasting', 2.1764082652091936),
#  ('remotely', 2.158003864182938),
#  ('poorly', 2.1452938714596423),
#  ('awful', 2.1437775732155773),
#  ('felix', 2.1231166051824975),
#  ('matthau', 2.1135745480492947),
#  ('existent', 2.058486176503848),
#  ('miserably', 1.9947297254219856),
#  ('boredom', 1.9887553331225925),
#  ('uninspired', 1.9869087128353191),
#  ('godzilla', 1.9753491564923438),
#  ('insult', 1.95207122152412),
#  ('gadget', 1.9513968717403196),
#  ('sucks', 1.9498478527339298),
#  ('appalling', 1.9347956737167715),
#  ('unintentional', 1.9336775806196789),
#  ('uninteresting', 1.9250424455055046),
#  ('lame', 1.9244797968107474),
#  ('polanski', 1.9070703157390494),
#  ('unconvincing', 1.9002255774440344),
#  ('idiotic', 1.89908269405373),
#  ('amateurish', 1.8877365380200837),
#  ('stupidity', 1.8782515005814986),
#  ('pathetic', 1.8560869814545125),
#  ('cardboard', 1.8557127957717292),
#  ('horrible', 1.852909797385675),
#  ('mildred', 1.8489178830680035),
#  ('gandhi', 1.8458266904983307),
#  ('insulting', 1.8325814637483102),
#  ('wonderfully', 1.8093346140495625),
#  ('flawless', 1.8091512119399242),
#  ('wasted', 1.7946439498889666),
#  ('tedious', 1.7876056716543487),
#  ('dire', 1.7844180623696873),
#  ('crap', 1.7771702783085046),
#  ('dreadful', 1.7556742569638946),
#  ('suck', 1.7514508139910367),
#  ('captures', 1.7311348474116202),
#  ('badly', 1.7123858816865427),
#  ('superbly', 1.7004096906398272),
#  ('embarrassing', 1.692116761661011),
#  ('perfection', 1.6894806201076369),
#  ('worse', 1.6887957871453698),
#  ('powell', 1.6810939013405355),
#  ('terrible', 1.6803828255720377),
#  ('pile', 1.6641696056246835),
#  ('garbage', 1.655981857524958),
#  ('mess', 1.6529290739989135),
#  ('worthless', 1.6470946318721054),
#  ('astaire', 1.6436292771823797),
#  ('ashamed', 1.6378519800634739),
#  ('beautifully', 1.6311189784954245),
#  ('superb', 1.6253815628312365),
#  ('vampires', 1.610364267294231),
#  ('stupid', 1.6102031564799313),
#  ('delightful', 1.5926307941177191),
#  ('inept', 1.5918515279320244),
#  ('fulci', 1.5887789985150274),
#  ('refreshing', 1.5764678931965306),
#  ('lincoln', 1.5712166996139025),
#  ('unbelievably', 1.5606477482646683),
#  ('forgettable', 1.5553412884793574),
#  ('wooden', 1.5539396902412972),
#  ('bourne', 1.550597412411167),
#  ('dull', 1.5496184781242275),
#  ('bat', 1.5478598502149126),
#  ('avoid', 1.5418366017659835),
#  ('flop', 1.5413978757024207),
#  ('topless', 1.5403733589285524),
#  ('crappy', 1.5336737595318182),
#  ('wonderful', 1.5336653539617702),
#  ('seed', 1.530064324892588),
#  ('ridiculously', 1.523623621302889),
#  ('touching', 1.5178707189086098),
#  ('breathtaking', 1.5178707189086098),
#  ('shark', 1.5155950843237251),
#  ('useless', 1.5117382452323942),
#  ('brosnan', 1.5085119938441398),
#  ('turkey', 1.5054359350657052),
#  ('junk', 1.50453204556792),
#  ('voight', 1.5040773967762742),
#  ('stewart', 1.5027994413307821),
#  ('rubbish', 1.501633576827613),
#  ('ripped', 1.5000690475099365),
#  ('whatsoever', 1.4995289332086228),
#  ('underrated', 1.496642418288756),
#  ('lily', 1.4954936530848826),
#  ('hideous', 1.4914159566953475),
#  ('excuse', 1.4903337479642529),
#  ('rambo', 1.4886094099905345),
#  ('disjointed', 1.481082937852318),
#  ('bakshi', 1.4781019103730135),
#  ('embarrassed', 1.4770515412937306),
#  ('ridiculous', 1.4751255748265064),
#  ('horrendous', 1.468203215742667),
#  ('welles', 1.4647659765613859),
#  ('boring', 1.4533306226714726),
#  ('plastic', 1.4489947793225262),
#  ('fest', 1.448169764837978),
#  ('fantastic', 1.444624526862802),
#  ('costs', 1.443370011609768),
#  ('flynn', 1.442989704796436),
#  ('excellent', 1.4418811889063683),
#  ('sinatra', 1.4360558706789543),
#  ('andrews', 1.4335472459704361),
#  ('unintentionally', 1.4320721179951306),
#  ('mummy', 1.4305946200164705),
#  ('horribly', 1.4239163529094747),
#  ('ludicrous', 1.4196936411473788),
#  ('bother', 1.4104126705687792),
#  ('obnoxious', 1.4104126705687792),
#  ('elvira', 1.409461420401425),
#  ('dinosaurs', 1.4077473290712037),
#  ('mildly', 1.406908055497103),
#  ('brilliantly', 1.4008931605410433),
#  ('dumb', 1.4005030444971995),
#  ('awake', 1.4001533962834427),
#  ('friendship', 1.3991425035977396),
#  ('terrific', 1.3947809749972093),
#  ('gripping', 1.3862943611198906),
#  ('bland', 1.3855959151337531),
#  ('noir', 1.3833831509124321),
#  ('outstanding', 1.3804634408090974),
#  ('meaningless', 1.3779085677436167),
#  ('finest', 1.377636298376776),
#  ('lemmon', 1.3758230612525952),
#  ('amateur', 1.373994623367175),
#  ('magnificent', 1.3679452224516941),
#  ('delight', 1.3639886036055924),
#  ('sullivan', 1.361601748529519),
#  ('favorites', 1.3609765531356006),
#  ('amazing', 1.3583335461222474),
#  ('clichd', 1.3470736479666092),
#  ('jackie', 1.3454723665996355),
#  ('extraordinary', 1.3391475826941888),
#  ('annoying', 1.3387472051900555),
#  ('kidding', 1.337003069403013),
#  ('mediocre', 1.3343346221891794),
#  ('miscast', 1.3314336669844282),
#  ('unless', 1.3296163231222042),
#  ('fails', 1.329602224786879),
#  ('apes', 1.3276404674281184),
#  ('freedom', 1.3230129111723705),
#  ('bad', 1.3193080892830453),
#  ('clich', 1.3181606156381687),
#  ('asleep', 1.3151764083944215),
#  ('marie', 1.3073671025302198),
#  ('clumsy', 1.306117883129788),
#  ('irritating', 1.3027619782074922),
#  ('dracula', 1.3014536230529388),
#  ('disappointment', 1.301236109751143),
#  ('utter', 1.2996534231046766),
#  ('unforgettable', 1.2992829841302609),
#  ('homer', 1.2992829841302609),
#  ('zombies', 1.2953976561105656),
#  ('nancy', 1.2939210409888755),
#  ('screaming', 1.2882034483550129),
#  ('soccer', 1.2878542883066382),
#  ('devoid', 1.284941866859603),
#  ('idiots', 1.2825589275692422),
#  ('disappointing', 1.2785649720435972),
#  ('gem', 1.275431768308081),
#  ('dude', 1.2739059673725293),
#  ('wannabe', 1.2729656758128873),
#  ('unbearable', 1.2632725466072279),
#  ('sadness', 1.2580400255962119),
#  ('timeless', 1.257676983297797),
#  ('unbelievable', 1.2550147856011589),
#  ('trite', 1.2531961331637802),
#  ('sidney', 1.252762968495368),
#  ('senseless', 1.2522458608392704),
#  ('supposed', 1.252044163352544),
#  ('kelly', 1.2498432583920334),
#  ('fake', 1.248116786649435),
#  ('poor', 1.2413030631715707),
#  ('coherent', 1.2393585863297485),
#  ('bin', 1.2393585863297485),
#  ('random', 1.2369202712542289),
#  ('scooby', 1.2354574363960786),
#  ('powerful', 1.2344883482518865),
#  ('favorite', 1.2342248474964568),
#  ('alright', 1.2279419944389323),
#  ('joke', 1.2262156535067872),
#  ('doo', 1.223108987078955),
#  ('toilet', 1.2228034271073782),
#  ('ritter', 1.2219913098286144),
#  ('perfect', 1.2218449290920579),
#  ('chan', 1.2201674902459168),
#  ('cheap', 1.2149217315658534),
#  ('bo', 1.214623638872469),
#  ('marvelous', 1.211635677071505),
#  ('generous', 1.2091142038263547),
#  ('monkey', 1.200947083409399),
#  ('idiot', 1.1993477547863738),
#  ('pretentious', 1.1984326239503205),
#  ('sucked', 1.197066018112681),
#  ('generic', 1.1968818994513666),
#  ('macy', 1.1962507582320256),
#  ('brilliant', 1.1960846314769298),
#  ('cabin', 1.1916941837131767),
#  ('tremendous', 1.1882244473577968),
#  ('stanwyck', 1.1863178690872151),
#  ('hartley', 1.1845547184688343),
#  ('sloppy', 1.1844369859961204),
#  ('renting', 1.1756733348045714),
#  ('shelf', 1.1748976960271837),
#  ('lazy', 1.1735403611896569),
#  ('widmark', 1.1727202608218317),
#  ('werewolf', 1.1726706342616864),
#  ('offensive', 1.171182981502945),
#  ('huh', 1.1683323524346048),
#  ('palma', 1.1676051601550612),
#  ('stunning', 1.166931532645587),
#  ('painfully', 1.1644850328188174),
#  ('cheese', 1.1637091051584163),
#  ('remarkable', 1.1623281030542174),
#  ('pleasantly', 1.1592369104845446),
#  ('mann', 1.1592369104845446),
#  ('disgusting', 1.1549136421723667),
#  ('retarded', 1.1540927217924783),
#  ('walked', 1.1528599933158254),
#  ('chilling', 1.1514547700424895),
#  ('exceptional', 1.1499055830556602),
#  ('journey', 1.149751250159297),
#  ('slightest', 1.1490721628594878),
#  ('poignant', 1.1474024528375417),
#  ('blame', 1.1392978296164809),
#  ('recommended', 1.1391036500228466),
#  ('blatant', 1.1383572771607269),
#  ('perfectly', 1.1381595857563642),
#  ('cringe', 1.1359680752118786),
#  ('loved', 1.1303906636553436),
#  ('ruth', 1.1293839473348635),
#  ('seconds', 1.1274173604373068),
#  ('favourite', 1.1263368366829647),
#  ('bond', 1.1216018068928084),
#  ('hoffman', 1.1121260078348325),
#  ('highly', 1.1101597610928817),
#  ('splendid', 1.1086626245216111),
#  ('notch', 1.1050020867668806),
#  ('trash', 1.104620016201758),
#  ('barbara', 1.1038893457689534),
#  ('flies', 1.10310512497974),
#  ('ugly', 1.0977036107318916),
#  ('warn', 1.0930182086536089),
#  ('pitt', 1.0920548881219507),
#  ('outer', 1.0918907429077829),
#  ('pseudo', 1.0903853533298191),
#  ('subtle', 1.0896436186853493),
#  ('fisher', 1.089042837651959),
#  ('davies', 1.089042837651959),
#  ('explanation', 1.0863864448428682),
#  ('gritty', 1.0857088838322018),
#  ('emotions', 1.081972969664145),
#  ('wrestling', 1.080541263536208),
#  ('clue', 1.08014745421359),
#  ('repetitive', 1.0788096613719298),
#  ('gentle', 1.0775588794702773),
#  ('today', 1.0764243736927475),
#  ('rare', 1.0751508019891116),
#  ('bette', 1.074514737089049),
#  ('ralph', 1.0732944806838198),
#  ('prince', 1.072969858054772),
#  ('tony', 1.0712813949511384),
#  ('motivation', 1.0690534864265653),
#  ('overrated', 1.0690534864265653),
#  ('oh', 1.0681664267934772),
#  ('captivating', 1.067840630001356),
#  ('sat', 1.0647856296646558),
#  ('bore', 1.0622871029410392),
#  ('cgi', 1.0613165039244128),
#  ('failed', 1.0611911926039375),
#  ('appreciated', 1.0601460078403135),
#  ('shines', 1.057112557761357),
#  ('burns', 1.0569395922675415),
#  ('paint', 1.0562762091651563),
#  ('paid', 1.055030469605816),
#  ('daniel', 1.050603069481749),
#  ('bored', 1.0499639282425342),
#  ('whale', 1.0486070575205095),
#  ('paper', 1.047228089321631),
#  ('darker', 1.0467872208035236),
#  ('painful', 1.041946658699986),
#  ('overlooked', 1.0414538748281612),
#  ('tender', 1.039423417277779),
#  ('absurd', 1.0365369049473558),
#  ('innocence', 1.0345904299031787),
#  ('halfway', 1.0339818599894601),
#  ('cole', 1.0334729864971484),
#  ('unique', 1.0334160891115678),
#  ('hype', 1.0334022640675002),
#  ('von', 1.0310189975355815),
#  ('philip', 1.0296194171811581),
#  ('cinderella', 1.0285027224810832),
#  ('porn', 1.0281438039251445),
#  ('haunting', 1.027349268646619),
#  ('nowhere', 1.0266239082013597),
#  ('aliens', 1.0261416008336075),
#  ('unrealistic', 1.0256273959116207),
#  ('noise', 1.02548120242428),
#  ('ensemble', 1.0245043165143877),
#  ('spending', 1.0242752322440638),
#  ('portrait', 1.0226263816901875),
#  ('awesome', 1.0219565444355891),
#  ('security', 1.0198491205349756),
#  ('secondly', 1.0135145061389195),
#  ('blake', 1.0116009116784799),
#  ('annoyed', 1.010650036470008),
#  ('predictable', 1.009964320590074),
#  ('contrived', 1.0098167898849786),
#  ('brain', 1.0085469206422129),
#  ('helps', 1.006998970745111),
#  ('vampire', 1.0069106702157904),
#  ('santa', 1.0066251596311973),
#  ('errors', 1.0042429902253387),
#  ('rat', 1.0042429902253387),
#  ('wreck', 1.0039323704431948),
#  ('sorry', 0.9989637072651866),
#  ('beauty', 0.9988228180597388),
#  ('bothered', 0.9979871049495201),
#  ('synopsis', 0.9954677095311742),
#  ('sounded', 0.9934576765599056),
#  ('carol', 0.9932517730102834),
#  ('april', 0.9932517730102834),
#  ('tragic', 0.9898094288193107),
#  ('intense', 0.9886113934537812),
#  ('crafted', 0.9886113934537812),
#  ('nominated', 0.9867639885315407),
#  ('lacks', 0.9844722442902273),
#  ('below', 0.9844722442902273),
#  ('provides', 0.9833770250905249),
#  ('gray', 0.9819409818644167),
#  ('psychiatrist', 0.9808292530117262),
#  ('greatest', 0.9802222727199496),
#  ('wanna', 0.9785554173722835),
#  ('breasts', 0.9772712338401021),
#  ('giallo', 0.9772514316638422),
#  ('save', 0.9770972485393332),
#  ('dollar', 0.9770704229651168),
#  ('contrast', 0.9769153536905899),
#  ('swear', 0.9763946559438605),
#  ('jimmy', 0.9711673420999893),
#  ('lesbian', 0.969093713707712),
#  ('flat', 0.9636566770802074),
#  ('bunch', 0.9632076516619068),
#  ('davis', 0.9608285863050567),
#  ('gore', 0.9600301134258075),
#  ('chick', 0.9600301134258075),
#  ('plain', 0.9599249707944743),
#  ('daughters', 0.958523495497428),
#  ('beautiful', 0.9583001399516979),
#  ('vivid', 0.9578397347870274),
#  ('troubled', 0.9572987556015322),
#  ('fascinating', 0.9568964868000981),
#  ('panic', 0.9555114450274363),
#  ('portrayal', 0.9544424978385313),
#  ('winters', 0.9531047049968714),
#  ('emma', 0.9529004774867161),
#  ('honestly', 0.9525926319866256),
#  ('oscar', 0.9494787231276501),
#  ('incredible', 0.9482737777272058),
#  ('mindless', 0.9463601686690154),
#  ('elvis', 0.9463601686690154),
#  ('unpleasant', 0.9433784518249034),
#  ('shallow', 0.9429243295219649),
#  ('unexpected', 0.9406491757061956),
#  ('ned', 0.9382696385929302),
#  ('grave', 0.9366351725913874),
#  ('fabulous', 0.9349828648863077),
#  ('f', 0.9348706343343036),
#  ('holly', 0.9343092373768334),
#  ('builds', 0.9332883082427261),
#  ('sweet', 0.933219793974603),
#  ('everyday', 0.9321640810304452),
#  ('sensitive', 0.9309968792638506),
#  ('curtis', 0.9301477665355813),
#  ('garbo', 0.9287132518727123),
#  ('heart', 0.9283548698010118),
#  ('rural', 0.9279867716373463),
#  ('ha', 0.9270628288560661),
#  ('ruined', 0.9264296770051058),
#  ('dentist', 0.9249487946172696),
#  ('minutes', 0.9233851260729399),
#  ('continuity', 0.9225603448877504),
#  ('harry', 0.9222431304014503),
#  ('nonsense', 0.9216790546218452),
#  ('courage', 0.9207253289420207),
#  ('implausible', 0.9207122571320324),
#  ('slap', 0.9176073877589019),
#  ('consequences', 0.9162907318741551),
#  ('unnecessary', 0.9154139234006206),
#  ('solid', 0.91220074662263),
#  ('somebody', 0.9115721521721607),
#  ('endless', 0.9111901257465673),
#  ('boxing', 0.9111493323737364),
#  ('terribly', 0.9109130606400365),
#  ('yeah', 0.9104816784416665),
#  ('brooklyn', 0.9102116857977729),
#  ('deeply', 0.9099549134250693),
#  ('celluloid', 0.9091732641052911),
#  ('seasons', 0.9078041179968362),
#  ('alexander', 0.9057086225436182),
#  ('downright', 0.9054343829083429),
#  ('complex', 0.9035110052277562),
#  ('snake', 0.9030072561616329),
#  ('ann', 0.9022389784185046),
#  ('throwing', 0.8990733923664819),
#  ('figured', 0.8985413861986228),
#  ('unfolds', 0.8979415932059586),
#  ('hollow', 0.8971567772876111),
#  ('presumably', 0.8965881495983179),
#  ('bible', 0.8963453392126104),
#  ('creates', 0.894431938061656),
#  ('hoping', 0.8932363896370942),
#  ('spectacular', 0.8919980393051105),
#  ('load', 0.8915981192837835),
#  ('happiness', 0.8914226652961417),
#  ('masterpiece', 0.8905478441810202),
#  ('credibility', 0.8874375141556267),
#  ('ape', 0.8856669037938187),
#  ('satisfying', 0.8855190732074014),
#  ('torture', 0.8849981613256858),
#  ('great', 0.8847027023315103),
#  ('rival', 0.883767540168595),
#  ('fat', 0.8820321011016604),
#  ('nudity', 0.8815100440421569),
#  ('disaster', 0.8812727823259503),
#  ('walter', 0.8803587226480917),
#  ('rented', 0.8798182638163506),
#  ('dramas', 0.879249460193806),
#  ('hong', 0.8782896136955411),
#  ('unusual', 0.8772402170022819),
#  ('feelings', 0.8768683177083232),
#  ('paris', 0.8761515642838107),
#  ('offended', 0.8736925379526441),
#  ('bettie', 0.8721954120089308),
#  ('rip', 0.8692098838918592),
#  ('themes', 0.8682815126877944),
#  ('bullets', 0.8662482193882571),
#  ('winning', 0.8659899933993561),
#  ('freak', 0.8648585582418844),
#  ('tears', 0.864465664009569),
#  ('inspiring', 0.8637726975907087),
#  ('draws', 0.8622235106038793),
#  ('jesus', 0.861986571851438),
#  ('vhs', 0.8619680501349973),
#  ('smooth', 0.861138911799075),
#  ('consists', 0.8607518754967267),
#  ('fx', 0.860280319731236),
#  ('wolf', 0.860280319731236),
#  ('charming', 0.8602012652231116),
#  ('ages', 0.8602012652231116),
#  ('season', 0.8588798246608161),
#  ('fay', 0.858226930919394),
#  ('drags', 0.857688355438488),
#  ('decent', 0.8567362011175645),
#  ('ok', 0.8533676677775117),
#  ('clichs', 0.8517522107365838),
#  ('raped', 0.8517522107365838),
#  ('cried', 0.8510502100057541),
#  ('warm', 0.8493079113152278),
#  ('z', 0.8492829517408229),
#  ('explained', 0.848003237312151),
#  ('christian', 0.8474213247987439),
#  ('danny', 0.8472978603872037),
#  ('debut', 0.8472978603872037),
#  ('touched', 0.8472978603872037),
#  ('threw', 0.8472203440118304),
#  ('enjoyed', 0.8465397102371662),
#  ('aunt', 0.8446970786871462),
#  ('carries', 0.8445468270153138),
#  ('learns', 0.8432655968592652),
#  ('priest', 0.8400550764797354),
#  ('weak', 0.839952284072509),
#  ('barely', 0.8394099765555801),
#  ('sake', 0.8388154197058645),
#  ('christ', 0.8388154197058645),
#  ('attempt', 0.8374361329231731),
#  ('impact', 0.837396789404492),
#  ('mature', 0.837396789404492),
#  ('depression', 0.8370413602200144),
#  ('terrifying', 0.8347976976229722),
#  ('musicals', 0.8344607136265229),
#  ('rose', 0.8323443107201453),
#  ('joy', 0.8300695564270263),
#  ('shy', 0.829722715565696),
#  ('clown', 0.8282128506316874),
#  ('knife', 0.8271981886807007),
#  ('stomach', 0.8268629219728967),
#  ('apparently', 0.8262391093232971),
#  ('bomb', 0.8261172113720476),
#  ('alas', 0.8215441969884631),
#  ('moving', 0.8209805520698303),
#  ('achievement', 0.819027426448948),
#  ('treat', 0.81860148671298),
#  ('dear', 0.8182736269395724),
#  ('supposedly', 0.8180355521067668),
#  ('funniest', 0.8177896257672219),
#  ('compelling', 0.8173375607913291),
#  ('loving', 0.8153648132841944),
#  ('strong', 0.814844115537465),
#  ('vague', 0.8142087807164791),
#  ('carrie', 0.81377516834856),
#  ('nothing', 0.8134333464344472),
#  ('episodes', 0.8109302162163288),
#  ('surprising', 0.8109302162163288),
#  ('throat', 0.8101696359656145),
#  ('blank', 0.8101696359656145),
#  ('anime', 0.8094861726440951),
#  ('lonely', 0.8091070616548137),
#  ('grim', 0.8091070616548137),
#  ('navy', 0.8088315795594077),
#  ('total', 0.8068947455310956),
#  ('natural', 0.8063535491889169),
#  ('fears', 0.8056251639866356),
#  ('couldn', 0.8054148610540464),
#  ('blend', 0.8050650967639307),
#  ('promising', 0.8050041017611451),
#  ('tragedy', 0.8041439565319697),
#  ('allows', 0.8040478765933871),
#  ('memorable', 0.8039950057040863),
#  ('castle', 0.8026657063664353),
#  ('quiet', 0.8023464725249373),
#  ('bottom', 0.801761414979721),
#  ('money', 0.8013704739851722),
#  ('lab', 0.8012324935439568),
#  ('balance', 0.8003927109135429),
#  ('substance', 0.7979488028121379),
#  ('cameras', 0.7974500546596361),
#  ('louis', 0.7971368940839929),
#  ('arthur', 0.7968256100347868),
#  ('warned', 0.7964101600528253),
#  ('mgm', 0.7954260296803636),
#  ('grade', 0.7946976494261369),
#  ('burn', 0.7938402431702765),
#  ('gorgeous', 0.7938357828570286),
#  ('zombie', 0.7933925955510012),
#  ('gag', 0.7933925955510012),
#  ('reasonable', 0.7914618693845689),
#  ('holmes', 0.790139446547255),
#  ('confusing', 0.788679607281509),
#  ('nose', 0.788679607281509),
#  ('daddy', 0.788679607281509),
#  ('stellar', 0.7884573603642703),
#  ('rental', 0.7871034386204235),
#  ('hank', 0.7859289140109116),
#  ('lovely', 0.7844386007693526),
#  ('holy', 0.7829431796766599),
#  ('lucas', 0.7827593392496325),
#  ('semi', 0.7822660398891398),
#  ('nicely', 0.7818752961686295),
#  ('smith', 0.780949384004393),
#  ('producers', 0.7809365795206283),
#  ('unfortunately', 0.7798842255559145),
#  ('sons', 0.7793248768009977),
#  ('accents', 0.7787495321394022),
#  ('stanley', 0.7786693539981072),
#  ('definite', 0.7770286645406473),
#  ('diana', 0.7753852787969173),
#  ('adorable', 0.7753852787969173),
#  ('adventure', 0.7750643030278321),
#  ('guilt', 0.7731898882334817),
#  ('glover', 0.7731898882334817),
#  ('glorious', 0.7731898882334817),
#  ('okay', 0.7726077284041342),
#  ('pie', 0.7723569019295898),
#  ('monster', 0.7722660065555564),
#  ('merit', 0.7713661554201894),
#  ('logic', 0.7710785246900405),
#  ('k', 0.7709903624926993),
#  ('execution', 0.7709903624926993),
#  ('spy', 0.7709248816026295),
#  ('realistic', 0.7703368192510752),
#  ('urban', 0.7695201593445192),
#  ('exercise', 0.7687153777207668),
#  ('thrillers', 0.7686547330680904),
#  ('hardcore', 0.7666958685827575),
#  ('essence', 0.7649729151312009),
#  ('dubbing', 0.7649501190384502),
#  ('sentence', 0.7642217833503385),
#  ('eerie', 0.7635279773217449),
#  ('witty', 0.7628805185746205),
#  ('winner', 0.7621400520468967),
#  ('seriously', 0.7619136470485538),
#  ('par', 0.7618755367695973),
#  ('damage', 0.7618755367695973),
#  ('ideal', 0.7602864833975739),
#  ('script', 0.759771047905812),
#  ('pg', 0.7594068081200528),
#  ('scientist', 0.7593228955099521),
#  ('joey', 0.7591051483517427),
#  ('premise', 0.7580359313709376),
#  ('carrey', 0.7576857016975165),
#  ('zero', 0.7565998716712814),
#  ('arm', 0.7561733323912108),
#  ('romero', 0.7555118210783978),
#  ('truck', 0.7543473648060588),
#  ('skip', 0.7540334645139083),
#  ('baseball', 0.7537718023763802),
#  ('fill', 0.7537339243058845),
#  ('overdone', 0.7535892347731963),
#  ('gratuitous', 0.7517546075134166),
#  ('doll', 0.7517546075134166),
#  ('alien', 0.7511321595299696),
#  ('rob', 0.7509667514487716),
#  ('write', 0.7500020351655677),
#  ('toys', 0.7497175320483396),
#  ('apartment', 0.7495612698400366),
#  ('throw', 0.7494351339215863),
#  ('reveals', 0.74806293815606),
#  ('derek', 0.747315417033095),
#  ('stiff', 0.7467219686852461),
#  ('hated', 0.7463057238940031),
#  ('slasher', 0.7446251642083404),
#  ('hooked', 0.7439195059333684),
#  ('childhood', 0.7427441216993175),
#  ('raw', 0.7419373447293773),
#  ('triumph', 0.7419373447293773),
#  ('margaret', 0.7419373447293773),
#  ('assume', 0.7417962503891734),
#  ('adds', 0.7410866428490643),
#  ('hoped', 0.7409378443962937),
#  ('subtitles', 0.738267615840415),
#  ('disbelief', 0.7376133732493227),
#  ('failure', 0.7369498032183383),
#  ('cox', 0.7357067949787413),
#  ('tale', 0.7347410778587823),
#  ('sadistic', 0.734220210603045),
#  ('performances', 0.733565053029843),
#  ('enterprise', 0.7328875092094594),
#  ('lovable', 0.7323678937132266),
#  ('guess', 0.7317907774260921),
#  ('silly', 0.7311431121495798),
#  ('italy', 0.7301884522402944),
#  ('cry', 0.7300517374953963),
#  ('lacked', 0.7299976712033508),
#  ('stock', 0.7293502292239059),
#  ('brazil', 0.7290791897860087),
#  ('stereotypical', 0.7288967597210281),
#  ('bucks', 0.728717421943224),
#  ('gross', 0.728011505095618),
#  ('meat', 0.7274937700711873),
#  ('shoot', 0.7270054946015831),
#  ('edge', 0.7265951146274854),
#  ('intentions', 0.725385431388809),
#  ('bush', 0.7241271942644357),
#  ('relate', 0.723918839226699),
#  ('blair', 0.7236063880446539),
#  ('leonard', 0.7223499486282029),
#  ('frank', 0.7221347174331975),
#  ('gonna', 0.7205788350206161),
#  ('proof', 0.7202398672870984),
#  ('thief', 0.7200546334798698),
#  ('annie', 0.720016579235654),
#  ('enjoyable', 0.719673934893374),
#  ('effort', 0.7195327539452014),
#  ('simple', 0.7194260650237857),
#  ('best', 0.7191835991031006),
#  ('advice', 0.717394837212839),
#  ('kung', 0.7169578292536639),
#  ('focuses', 0.7166776779701394),
#  ('instead', 0.7164268133819439),
#  ('relationship', 0.7163142398414797),
#  ('nuclear', 0.7159585850090516),
#  ('magical', 0.7152883064371588),
#  ('impressed', 0.713937950229019),
#  ('stick', 0.7136026524917647),
#  ('thin', 0.7133498878774648),
#  ('melting', 0.7133498878774648),
#  ('supporting', 0.7130153837766705),
#  ('holds', 0.7125652664170469),
#  ('spare', 0.7112853710151457),
#  ('relies', 0.7112853710151457),
#  ('strength', 0.7108467576593461),
#  ('jean', 0.709814233045157),
#  ('hills', 0.7096461799399804),
#  ('sum', 0.7089862445896914),
#  ('weren', 0.708771566627277),
#  ('makeup', 0.707735838044698),
#  ('ah', 0.707735838044698),
#  ('widow', 0.706219262127298),
#  ('originality', 0.7060165216796688),
#  ('sport', 0.705886206337375),
#  ('satan', 0.7054809948155538),
#  ('rex', 0.7054809948155538),
#  ('animated', 0.7045758763835681),
#  ('perry', 0.7044467358138787),
#  ('demon', 0.7039748192120087),
#  ('gene', 0.7036184804272407),
#  ('winter', 0.7032995520239632),
#  ('colorful', 0.7029033555053099),
#  ('suppose', 0.7023868151124578),
#  ('essential', 0.7018808605286999),
#  ('none', 0.7017555550965455),
#  ('lying', 0.7017555550965455),
#  ('rent', 0.7016384138123087),
#  ('deeper', 0.7011793522572095),
#  ('screenwriter', 0.6992527381224304),
#  ('lacking', 0.6990714300750293),
#  ('traditional', 0.6987494361086151),
#  ('deals', 0.6987494361086151),
#  ('albert', 0.6986266463245708),
#  ('im', 0.6969639790866462),
#  ('handed', 0.6964083062080768),
#  ('emotional', 0.6953969002939608),
#  ('forest', 0.6953718755820565),
#  ('lou', 0.6953718755820565),
#  ('saved', 0.6939808613085228),
#  ('columbo', 0.6931471805599453),
#  ('princess', 0.6931471805599453),
#  ('intensity', 0.6931471805599453),
#  ('loser', 0.6931471805599453),
#  ('comfortable', 0.6931471805599453),
#  ('ginger', 0.6931471805599453),
#  ('destiny', 0.6931471805599453),
#  ('awe', 0.6931471805599453),
#  ('tried', 0.6902941115775388),
#  ('channel', 0.6896549357166246),
#  ('fresh', 0.6892636805335477),
#  ('empty', 0.6888631763067702),
#  ('brings', 0.688463331247519),
#  ('love', 0.6878138345845827),
#  ('whoever', 0.6872491154349583),
#  ('judging', 0.6865026378412769),
#  ('surreal', 0.6862743012721833),
#  ('rick', 0.6861586701708462),
#  ('realizes', 0.6859786910813328),
#  ('thugs', 0.6855220052547245),
#  ('intent', 0.6849456114465275),
#  ('sole', 0.6846774034764612),
#  ('society', 0.6844135005911908),
#  ('lucy', 0.6843365508777904),
#  ('dragged', 0.683296864709111),
#  ('pleased', 0.682218110027755),
#  ('norman', 0.682218110027755),
#  ('captured', 0.6820973443733603),
#  ('subsequent', 0.6817184847363226),
#  ('gradually', 0.6814511407967541),
#  ('racist', 0.6812186096946715),
#  ('performance', 0.6787288051356736),
#  ('spent', 0.6760341729594025),
#  ('portraying', 0.6742191706744264),
#  ('hearted', 0.6739772644522252),
#  ('worlds', 0.6737290947028437),
#  ('looked', 0.6733445532637656),
#  ('holes', 0.6733445532637656),
#  ('deserve', 0.6733445532637656),
#  ('sequels', 0.6733445532637656),
#  ('propaganda', 0.6733445532637656),
#  ('convince', 0.6733445532637656),
#  ('flash', 0.6733445532637656),
#  ('jerk', 0.6733445532637656),
#  ('fifteen', 0.6733445532637656),
#  ('corpse', 0.6733445532637656),
#  ('reasonably', 0.6733445532637656),
#  ('minimal', 0.6733445532637656),
#  ('juvenile', 0.6733445532637656),
#  ('eastwood', 0.6729444732424258),
#  ('touches', 0.6723851891115162),
#  ('kudos', 0.6711682738411701),
#  ('atmosphere', 0.6710800865312667),
#  ('makers', 0.6704047581079579),
#  ('tight', 0.6697998165629542),
#  ('mean', 0.6690044193720184),
#  ('watchable', 0.6687089061713866),
#  ('monsters', 0.6682247386806499),
#  ('flesh', 0.6676276385393697),
#  ('mysteries', 0.6671716941566846),
#  ('hal', 0.6671716941566846),
#  ('romantic', 0.6655592240411162),
#  ('sings', 0.664976303593249),
#  ('drink', 0.6640508060723062),
#  ('virus', 0.6634903150675254),
#  ('jim', 0.6631148934610702),
#  ('health', 0.6626879730752367),
#  ('rules', 0.6621849549559784),
#  ('laurel', 0.6621386986666916),
#  ('convoluted', 0.6621386986666916),
#  ('magic', 0.6619920127801497),
#  ('studios', 0.6618946370558408),
#  ('con', 0.6618946370558408),
#  ('asian', 0.6614594597142092),
#  ('henry', 0.6609440400653106),
#  ('utterly', 0.6606925626340847),
#  ('paul', 0.6602494770528863),
#  ('hour', 0.6586362428092668),
#  ('bleak', 0.6584616225720553),
#  ('jake', 0.6580558607486753),
#  ('danes', 0.6576404921030355),
#  ('lack', 0.6568642857429073),
#  ('secrets', 0.6567795363890705),
#  ('mistake', 0.6565249963699277),
#  ('low', 0.6563191395879919),
#  ('legendary', 0.6562426236244944),
#  ('shower', 0.6559890325930124),
#  ('available', 0.6556896180250449),
#  ('kennedy', 0.6549259677397475),
#  ('both', 0.6547480476254093),
#  ('cover', 0.6541973599994082),
#  ('meets', 0.6540966656880721),
#  ('lifestyle', 0.653926467406664),
#  ('works', 0.6538357603450571),
#  ('lovers', 0.6535380424648994),
#  ('steals', 0.6528732814220054),
#  ('killings', 0.6526997242554784),
#  ('creature', 0.6523459654763604),
#  ('hire', 0.6522556232418463),
#  ('reason', 0.6519853474183193),
#  ('memories', 0.6519042220258962),
#  ('sharp', 0.651761964397091),
#  ('match', 0.6512174874218214),
#  ('favor', 0.6508007671614454),
#  ('conceived', 0.6508007671614454),
#  ('charlie', 0.6500227539261906),
#  ('manager', 0.6490871907659148),
#  ('fail', 0.6485170615432827),
#  ('genius', 0.6481234991859902),
#  ('props', 0.6478719584979576),
#  ('wouldn', 0.64719243522532),
#  ('akshay', 0.64719243522532),
#  ('avoided', 0.64719243522532),
#  ('city', 0.6462828715837275),
#  ('millions', 0.6457184869888345),
#  ('definitely', 0.6454076525787912),
#  ('delivers', 0.6443570163905132),
#  ('todd', 0.6443570163905132),
#  ('saying', 0.6442513695677432),
#  ('neither', 0.6439086272867687),
#  ('golden', 0.6435502394205732),
#  ('colors', 0.6433148068120695),
#  ('thats', 0.6431672482549246),
#  ('surprisingly', 0.6431367599852839),
#  ('tear', 0.642885345779057),
#  ('court', 0.6418538861723947),
#  ('highest', 0.6418538861723947),
#  ('relationships', 0.6410311794209312),
#  ('unlike', 0.6405693644800381),
#  ('root', 0.640096810045503),
#  ('father', 0.6394195755265898),
#  ('driven', 0.6394029045532547),
#  ('failing', 0.6393276679855112),
#  ('freddy', 0.6391013327481097),
#  ('nevertheless', 0.6387531084941465),
#  ('kapoor', 0.637677434515584),
#  ('please', 0.6373754237254632),
#  ('trek', 0.6372667221654887),
#  ('dancer', 0.6370577139089018),
#  ('environment', 0.6369074622370692),
#  ('rain', 0.6367942440088136),
#  ('easy', 0.6364073519081931),
#  ('lewis', 0.6359887667199967),
#  ('amy', 0.6348782724359695),
#  ('pregnant', 0.6342648695644127),
#  ('outfit', 0.6338449476217304),
#  ('fonda', 0.6317782341836532),
#  ('sides', 0.6309048716827245),
#  ('disagree', 0.6299682789384138),
#  ('string', 0.6297456692094493),
#  ('future', 0.6294521854108134),
#  ('streets', 0.6292957085734125),
#  ('owner', 0.6279066586915444),
#  ('loosely', 0.6277162006393544),
#  ('kurt', 0.6273958029971649),
#  ('category', 0.6271011755576966),
#  ('remake', 0.6265702499594236),
#  ('craig', 0.6257058997644128),
#  ('modesty', 0.6257058997644128),
#  ('effective', 0.6249389305334118),
#  ('brains', 0.624291070561172),
#  ('stays', 0.6236211179113351),
#  ('politically', 0.6230321319318071),
#  ('purple', 0.6225296133459919),
#  ('mouth', 0.6221563064103207),
#  ('ya', 0.621706856080499),
#  ('paying', 0.6207166550284025),
#  ('award', 0.62057648772511),
#  ('che', 0.6200249157309827),
#  ('weekend', 0.6195826155825069),
#  ('ride', 0.6195588239024562),
#  ('titanic', 0.6190392084062235),
#  ('sunday', 0.6190392084062235),
#  ('germany', 0.6181119946170313),
#  ('oscars', 0.6176396280518002),
#  ('gives', 0.6175161897663776),
#  ('ad', 0.6172760577878426),
#  ('sky', 0.6170478370212982),
#  ('dreams', 0.6165706808628951),
#  ('develops', 0.616186139423817),
#  ('competent', 0.6150529948266482),
#  ('sees', 0.6146224174476342),
#  ('bare', 0.6145870528466316),
#  ('simon', 0.614366302706831),
#  ('midnight', 0.614366302706831),
#  ('master', 0.6133600639421134),
#  ('robots', 0.6131434220382961),
#  ('maria', 0.6131044728864089),
#  ('portrays', 0.6126083180759331),
#  ('franchise', 0.6111796550779478),
#  ('classic', 0.6110415531243946),
#  ('tense', 0.6109090823229731),
#  ('stereotypes', 0.6107672707587903),
#  ('jack', 0.6105605895506713),
#  ('appreciate', 0.6101238447482711),
#  ('dialog', 0.6097907687887338),
#  ('miike', 0.6097655716208943),
#  ('sir', 0.6088060321261943),
#  ('why', 0.6085848120382966),
#  ('except', 0.6082173763466768),
#  ('shut', 0.6079190017189233),
#  ('era', 0.6077873316087886),
#  ('sentimental', 0.6077873316087886),
#  ('fantasy', 0.6077019746030605),
#  ('andy', 0.6077019746030605),
#  ('flick', 0.6067695798281503),
#  ('dan', 0.6061358035703155),
#  ('cant', 0.6052320726246205),
#  ('research', 0.6043603386986726),
#  ('identity', 0.6041996945434491),
#  ('scare', 0.6034659926133307),
#  ('personal', 0.602912593688747),
#  ('cash', 0.6023928172914812),
#  ('frankly', 0.6022608546103358),
#  ('forbidden', 0.6021754023542185),
#  ('reunion', 0.6013396313068224),
#  ('animation', 0.6012096852342597),
#  ('importance', 0.6007738604289301),
#  ('experiment', 0.6006381230353321),
#  ('dialogues', 0.6006381230353321),
#  ('dave', 0.6000567574939334),
#  ('emotionally', 0.5989599655002442),
#  ('william', 0.598069531857703),
#  ('problem', 0.5976835794604438),
#  ('dimensional', 0.5965693056777576),
#  ('leslie', 0.5962973545700276),
#  ('jane', 0.5957250675524769),
#  ('naked', 0.5953323031406113),
#  ('abc', 0.5947071077466928),
#  ('achieved', 0.5940562779157145),
#  ('dont', 0.5939017092755653),
#  ('guy', 0.5932055760354016),
#  ('pointed', 0.5932055760354016),
#  ('nowadays', 0.5930637220029628),
#  ('marriage', 0.5928905768202949),
#  ('gothic', 0.5920510636885765),
#  ('anger', 0.5908683314395271),
#  ('hell', 0.5904179263267681),
#  ('explicit', 0.590199211307503),
#  ('strictly', 0.5897886675727921),
#  ('remote', 0.5894308730146083),
#  ('china', 0.5893503868783018),
#  ('least', 0.5882924830589068),
#  ('conspiracy', 0.5879684996148666),
#  ('bullet', 0.5879684996148666),
#  ('paced', 0.5877866649021191),
#  ('roy', 0.5877866649021191),
#  ('depiction', 0.5877866649021191),
#  ('job', 0.5873785849127792),
#  ('always', 0.5869249673046378),
#  ('influence', 0.5863792051342392),
#  ('scientists', 0.5862826418728315),
#  ('page', 0.5862314546353126),
#  ('fine', 0.5859214277094386),
#  ('crack', 0.585788662239446),
#  ('denzel', 0.5857269319391084),
#  ('deaths', 0.5856163598483239),
#  ('provoking', 0.5842530923208079),
#  ('warrior', 0.584079260113797),
#  ('cheesy', 0.5832584711253854),
#  ('luke', 0.5831462853456169),
#  ('donald', 0.5831462853456169),
#  ('empire', 0.5831462853456169),
#  ('dry', 0.5827028352970284),
#  ('inspired', 0.5816917396346225),
#  ('covers', 0.5813557745718286),
#  ('england', 0.5808798786888641),
#  ('nature', 0.5804384580750311),
#  ('somewhere', 0.5792571074876791),
#  ('packed', 0.5784842722398056),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note：: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('subtlety', -0.009950330853168092),
#  ('crush', -0.009950330853168092),
#  ('dutch', -0.009950330853168092),
#  ('surviving', -0.009950330853168092),
#  ('primarily', -0.009950330853168092),
#  ('punk', -0.009950330853168092),
#  ('passes', -0.009950330853168092),
#  ('yellow', -0.009950330853168092),
#  ('scheme', -0.009950330853168092),
#  ('groups', -0.009950330853168092),
#  ('escaped', -0.009950330853168092),
#  ('proceedings', -0.009950330853168092),
#  ('swedish', -0.009950330853168092),
#  ('birds', -0.009950330853168092),
#  ('imagined', -0.009950330853168092),
#  ('craven', -0.009950330853168092),
#  ('rid', -0.009950330853168092),
#  ('watches', -0.009950330853168092),
#  ('push', -0.009950330853168092),
#  ('menacing', -0.009950330853168092),
#  ('row', -0.009950330853168092),
#  ('infamous', -0.009950330853168092),
#  ('suffered', -0.009950330853168092),
#  ('suspects', -0.009950330853168092),
#  ('mass', -0.009950330853168092),
#  ('raise', -0.009950330853168092),
#  ('underground', -0.009950330853168092),
#  ('closing', -0.009950330853168092),
#  ('significant', -0.009950330853168092),
#  ('lugosi', -0.009950330853168092)]

# %% [markdown]
# # 项目 1 到此结束
# ## 请进入下一个视频，观看  Andrew 的解决方案，然后继续学习下一课。
#
# # 将文本转换成数字<a id='lesson_3'></a>
# 此代码框包含 Andrew 在下一个视频中使用的代码，因此你无需手动输入，即可跟着视频运行代码。

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # 项目 2：创建输入/输出数据<a id='project_2'></a>
#
# **待办：** 创建一个名为 `vocab` 的[集合](https://docs.python.org/3/tutorial/datastructures.html#sets)，将词汇表的所有单词放入其中。

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set([word for word in total_counts])
vocab
# Out:
# {'',
#  'although',
#  'pullout',
#  'oddities',
#  'therefrom',
#  'belly',
#  'explodes',
#  'saintliness',
#  'reverted',
#  'wrestled',
#  'romany',
#  'obtuse',
#  'contemplations',
#  'ventura',
#  'karadzhic',
#  'ron',
#  'thrusted',
#  'sentinels',
#  'poalher',
#  'tremor',
#  'koi',
#  'boyens',
#  'tased',
#  'apollo',
#  'stabilize',
#  'stewarts',
#  'translating',
#  'unthinkable',
#  'lei',
#  'encasing',
#  'livelier',
#  'brilliancy',
#  'mcconnahay',
#  'straitjacketed',
#  'unmentionable',
#  'param',
#  'etat',
#  'twang',
#  'tastes',
#  'spiritless',
#  'ok',
#  'boneheads',
#  'stensvold',
#  'representing',
#  'spouses',
#  'boffo',
#  'bergmanesque',
#  'vacuously',
#  'owned',
#  'reinas',
#  'entombed',
#  'nadia',
#  'handguns',
#  'ontkean',
#  'estelle',
#  'materializes',
#  'jafar',
#  'lining',
#  'appliances',
#  'borstein',
#  'swartzenegger',
#  'mdchen',
#  'dolomites',
#  'damages',
#  'shipping',
#  'heartrending',
#  'resistor',
#  'ophuls',
#  'motorcross',
#  'roland',
#  'idly',
#  'imaginations',
#  'chancery',
#  'snuggled',
#  'who',
#  'akhtar',
#  'worries',
#  'savaging',
#  'reiterate',
#  'segregating',
#  'robust',
#  'tohs',
#  'settle',
#  'aforementioned',
#  'coveys',
#  'bantam',
#  'spotter',
#  'meurent',
#  'temporality',
#  'propelling',
#  'beeping',
#  'coote',
#  'uprosing',
#  'baboushka',
#  'br',
#  'avery',
#  'anastasia',
#  'hospitals',
#  'troopers',
#  'refresh',
#  'kanmuri',
#  'mmpr',
#  'suckiest',
#  'tastic',
#  'nausea',
#  'manchurian',
#  'bukvic',
#  'detachment',
#  'skelter',
#  'jolt',
#  'brits',
#  'saturnine',
#  'stewardesses',
#  'heigel',
#  'pakage',
#  'soundly',
#  'relabeled',
#  'brd',
#  'influence',
#  'technologies',
#  'depress',
#  'libertine',
#  'nantes',
#  'nicodemus',
#  'lacks',
#  'leadenly',
#  'hms',
#  'doel',
#  'tykes',
#  'bled',
#  'chamberlin',
#  'tumour',
#  'beckinsales',
#  'mran',
#  'bottle',
#  'tridev',
#  'plently',
#  'figg',
#  'weekly',
#  'crumbled',
#  'cemented',
#  'vamps',
#  'woof',
#  'metin',
#  'whotta',
#  'rabified',
#  'incinerator',
#  'wannabes',
#  'exciter',
#  'sabers',
#  'frisk',
#  'audiard',
#  'scates',
#  'rainn',
#  'compatriots',
#  'regimens',
#  'tandy',
#  'feasibly',
#  'dulling',
#  'gratingly',
#  'illusions',
#  'demons',
#  'saalistajat',
#  'pappas',
#  'sashays',
#  'induced',
#  'truax',
#  'kalama',
#  'stethoscope',
#  'scarfs',
#  'coorain',
#  'evidenced',
#  'sopisticated',
#  'thorstenson',
#  'soar',
#  'decoder',
#  'willing',
#  'ambient',
#  'kiera',
#  'r',
#  'husbands',
#  'burr',
#  'proby',
#  'deodato',
#  'relationships',
#  'lepage',
#  'italianised',
#  'cinemademerde',
#  'dodgerdude',
#  'nike',
#  'perceval',
#  'ardh',
#  'believability',
#  'erschbamer',
#  'er',
#  'lala',
#  'lacrosse',
#  'beirut',
#  'horrified',
#  'gained',
#  'benvolio',
#  'ponder',
#  'nozzle',
#  'snowbell',
#  'hampered',
#  'zimmerman',
#  'carolingians',
#  'kinetics',
#  'facility',
#  'kitted',
#  'zarustica',
#  'missions',
#  'lawns',
#  'barbarellish',
#  'retiree',
#  'sacrilage',
#  'storyboard',
#  'blankfield',
#  'granger',
#  'nutzo',
#  'cataloguing',
#  'joliet',
#  'tristran',
#  'beaters',
#  'muerte',
#  'marcel',
#  'palatial',
#  'fiancs',
#  'bams',
#  'graininess',
#  'muldaur',
#  'burstyn',
#  'conspicious',
#  'abruptness',
#  'qualitys',
#  'multiculturalism',
#  'physco',
#  'necron',
#  'oracles',
#  'fortuitous',
#  'weeps',
#  'callahan',
#  'likeliness',
#  'redistribute',
#  'snatchers',
#  'drawbacks',
#  'devotional',
#  'overview',
#  'supertroopers',
#  'leeringly',
#  'dryer',
#  'promotes',
#  'runner',
#  'goldie',
#  'aaghh',
#  'vicitm',
#  'leprous',
#  'dahl',
#  'sanguisuga',
#  'gaolers',
#  'granzow',
#  'vindictively',
#  'jurassic',
#  'insupportable',
#  'assign',
#  'dethaw',
#  'deconstructed',
#  'nnette',
#  'laroche',
#  'pyke',
#  'aprox',
#  'manouvres',
#  'tool',
#  'sobs',
#  'chepart',
#  'kitley',
#  'dia',
#  'stripped',
#  'impossibility',
#  'chappu',
#  'smarmiest',
#  'pollutes',
#  'bavarian',
#  'followups',
#  'blystone',
#  'mimetic',
#  'rostov',
#  'kappor',
#  'demystifying',
#  'emanating',
#  'dish',
#  'taxing',
#  'intoxicating',
#  'pumped',
#  'loggins',
#  'resets',
#  'azema',
#  'nose',
#  'pancreatitis',
#  'beech',
#  'sogo',
#  'tyranosaurous',
#  'leitmotivs',
#  'allures',
#  'todd',
#  'monument',
#  'admarible',
#  'macanally',
#  'strutts',
#  'churchill',
#  'trotting',
#  'fightm',
#  'aussies',
#  'pasa',
#  'criminology',
#  'marco',
#  'nevada',
#  'prescreening',
#  'inebriation',
#  'starringsean',
#  'connecticute',
#  'scorned',
#  'mancori',
#  'sensitivity',
#  'anger',
#  'decade',
#  'spooky',
#  'grieg',
#  'dropping',
#  'supposibly',
#  'lavishly',
#  'matriculates',
#  'hadj',
#  'raghubir',
#  'alleging',
#  'convincedness',
#  'sedative',
#  'whilhelm',
#  'accessability',
#  'tormento',
#  'shroyer',
#  'sillier',
#  'orb',
#  'katy',
#  'koteas',
#  'hellbound',
#  'settlefor',
#  'offhand',
#  'innumerable',
#  'fascinatingly',
#  'sharpshooter',
#  'hentai',
#  'dimmed',
#  'continental',
#  'vasectomies',
#  'directorial',
#  'your',
#  'chess',
#  'hautefeuille',
#  'hatley',
#  'netherlands',
#  'oland',
#  'bell',
#  'blakes',
#  'fathoming',
#  'padm',
#  'environs',
#  'monopolies',
#  'guillaumme',
#  'draza',
#  'quasirealistic',
#  'electricity',
#  'unjust',
#  'checkpoints',
#  'boricua',
#  'talia',
#  'conditioning',
#  'anupamji',
#  'consecutive',
#  'broker',
#  'dantesque',
#  'unaccomplished',
#  'eisenmann',
#  'undead',
#  'pasqal',
#  'pascow',
#  'schlettow',
#  'narration',
#  'bedfellows',
#  'differential',
#  'habituation',
#  'collective',
#  'roubaix',
#  'efenstor',
#  'springing',
#  'lebrock',
#  'cheswick',
#  'grinding',
#  'chortle',
#  'delightful',
#  'terry',
#  'ozkan',
#  'watershed',
#  'liqueur',
#  'dekhiye',
#  'favoritism',
#  'mobocracy',
#  'eccelston',
#  'hallelujah',
#  'joxs',
#  'booke',
#  'euthenased',
#  'asphalt',
#  'argentina',
#  'bureacracy',
#  'railroads',
#  'merlet',
#  'showcased',
#  'diary',
#  'sympathized',
#  'chiani',
#  'rug',
#  'paint',
#  'contributers',
#  'readiness',
#  'recieves',
#  'pursuing',
#  'radiating',
#  'dramatizing',
#  'sods',
#  'gundam',
#  'masterpeice',
#  'uhs',
#  'storied',
#  'thc',
#  'ripping',
#  'oops',
#  'zorba',
#  'gaga',
#  'nappy',
#  'holey',
#  'pooling',
#  'stumped',
#  'hotly',
#  'doodo',
#  'chonopolisians',
#  'littlefield',
#  'edition',
#  'cardboard',
#  'ebay',
#  'donnacha',
#  'unaccpectable',
#  'fluke',
#  'neutering',
#  'eeks',
#  'evocatively',
#  'culinary',
#  'duuum',
#  'adherents',
#  'jimi',
#  'cliques',
#  'overstyling',
#  'radiohead',
#  'formulatic',
#  'shock',
#  'hammish',
#  'sunnydale',
#  'fortunate',
#  'kayak',
#  'unwarily',
#  'hypothermia',
#  'validity',
#  'confusion',
#  'nope',
#  'bedtime',
#  'rustle',
#  'rambunctious',
#  'inexcusably',
#  'sprinkled',
#  'matt',
#  'latecomer',
#  'fratboy',
#  'circumcision',
#  'shampoo',
#  'tempo',
#  'calleia',
#  'boars',
#  'wresting',
#  'rakastin',
#  'marafon',
#  'harrisonfirst',
#  'shoddiest',
#  'mall',
#  'utility',
#  'chinatown',
#  'vileness',
#  'recriminations',
#  'solidity',
#  'tersteeghe',
#  'liquefied',
#  'incentive',
#  'sorts',
#  'meandering',
#  'shibasaki',
#  'tusk',
#  'duddy',
#  'bewilder',
#  'lubricated',
#  'gear',
#  'snoopy',
#  'fight',
#  'inexplicable',
#  'tazmanian',
#  'redstacey',
#  'alyce',
#  'seger',
#  'douce',
#  'dancehall',
#  'devil',
#  'flair',
#  'misfortune',
#  'myeres',
#  'gitai',
#  'maze',
#  'inconsistancies',
#  'citta',
#  'identical',
#  'durable',
#  'vaxham',
#  'anglo',
#  'bragging',
#  'giegud',
#  'flirting',
#  'mesquida',
#  'dip',
#  'crowell',
#  'noway',
#  'odin',
#  'daslow',
#  'emitting',
#  'stoppage',
#  'hedged',
#  'antartic',
#  'lasciviousness',
#  'persecution',
#  'fanshawe',
#  'strobing',
#  'heatbreaking',
#  'menace',
#  'phobias',
#  'hool',
#  'gad',
#  'mutterings',
#  'poet',
#  'inconsistencies',
#  'nallae',
#  'ratings',
#  'gould',
#  'thata',
#  'anecdote',
#  'rail',
#  'depardeu',
#  'rungs',
#  'capulet',
#  'explorer',
#  'seascape',
#  'employee',
#  'twentysomething',
#  'renal',
#  'windup',
#  'shellshocked',
#  'clinkers',
#  'diatribe',
#  'cloned',
#  'meatlocker',
#  'auditorium',
#  'revitalizes',
#  'gaylord',
#  'coutard',
#  'bones',
#  'banderas',
#  'births',
#  'fosse',
#  'sunroof',
#  'blush',
#  'gordon',
#  'chagrin',
#  'ghostbuster',
#  'celebrations',
#  'fetuccini',
#  'planetary',
#  'rifted',
#  'long',
#  'scholastic',
#  'adversities',
#  'equidor',
#  'neglect',
#  'dastak',
#  'gojn',
#  'hires',
#  'airing',
#  'bunny',
#  'unbelievable',
#  'lang',
#  'mohawk',
#  'purr',
#  'termites',
#  'often',
#  'pliant',
#  'firguring',
#  'evaporated',
#  'fawn',
#  'creepies',
#  'pollinating',
#  'berzier',
#  'suffice',
#  'manchus',
#  'baltic',
#  'mutinous',
#  'landmines',
#  'knows',
#  'alekos',
#  'addressing',
#  'dvr',
#  'matteo',
#  'behold',
#  'hypnosis',
#  'herbie',
#  'pain',
#  'keanu',
#  'virulently',
#  'dishwater',
#  'moxy',
#  'dinky',
#  'plywood',
#  'spawned',
#  'bewafaa',
#  'foothold',
#  'indiains',
#  'elivates',
#  'micheals',
#  'battre',
#  'gregarious',
#  'yar',
#  'aerodynamics',
#  'nonchalant',
#  'appear',
#  'favreau',
#  'manon',
#  'waves',
#  'tuvoks',
#  'sensuous',
#  'howes',
#  'ververgaert',
#  'changeling',
#  'stinking',
#  'humanity',
#  'grapes',
#  'journos',
#  'beautifully',
#  'reunion',
#  'vocational',
#  'deploys',
#  'americana',
#  'infighting',
#  'shakesphere',
#  'coupledom',
#  'objectively',
#  'acharya',
#  'kidnapper',
#  'straighten',
#  'streep',
#  'queries',
#  'theat',
#  'thirsty',
#  'computeranimation',
#  'textural',
#  'coonskin',
#  'trio',
#  'scouted',
#  'referendum',
#  'cuticle',
#  'paperwork',
#  'forewarns',
#  'alchoholic',
#  'tyrants',
#  'saucy',
#  'mallrats',
#  'zigfield',
#  'jeanane',
#  'thinking',
#  'realized',
#  'conran',
#  'semple',
#  'masculin',
#  'dramatize',
#  'meddlesome',
#  'appreciative',
#  'kabaree',
#  'constitutionally',
#  'bookman',
#  'hystericalness',
#  'gospel',
#  'heinkel',
#  'tomcat',
#  'klugman',
#  'gymnast',
#  'wilco',
#  'waterstone',
#  'ooohhh',
#  'realityshowlike',
#  'plugs',
#  'bickering',
#  'drudge',
#  'demands',
#  'perplexities',
#  'dumbs',
#  'nomadic',
#  'slickers',
#  'suleiman',
#  'susi',
#  'moshpit',
#  'jitters',
#  'sickness',
#  'wazoo',
#  'norse',
#  'shillings',
#  'montazuma',
#  'shaloub',
#  'gretel',
#  'expanding',
#  'majors',
#  'outdated',
#  'coool',
#  'repellent',
#  'starlet',
#  'broader',
#  'rockies',
#  'kernel',
#  'initial',
#  'earths',
#  'eschelons',
#  'rebe',
#  'jungle',
#  'creasey',
#  'bigg',
#  'encapsulated',
#  'deadbeat',
#  'bangster',
#  'wounds',
#  'fixation',
#  'password',
#  'alicianne',
#  'cccc',
#  'ranches',
#  'handless',
#  'nosedive',
#  'kearn',
#  'samwise',
#  'montmirail',
#  'unachieving',
#  'depriving',
#  'disrobes',
#  'smooshed',
#  'molemen',
#  'chessy',
#  'anyhows',
#  'flourishing',
#  'iciness',
#  'referat',
#  'gruff',
#  'argufying',
#  'anno',
#  'stows',
#  'pados',
#  'weaponry',
#  'harvester',
#  'modifies',
#  'smelly',
#  'unseemly',
#  'cheddar',
#  'overfed',
#  'erupts',
#  'fairly',
#  'algrant',
#  'jiggle',
#  'shriver',
#  'caution',
#  'lanka',
#  'darius',
#  'nettie',
#  'invesment',
#  'also',
#  'harf',
#  'conscientious',
#  'mysteries',
#  'cheapen',
#  'bergin',
#  'reservedly',
#  'hellishly',
#  'slashing',
#  'crasser',
#  'handwriting',
#  'unidentified',
#  'advani',
#  'ethnographer',
#  'pontificating',
#  'authentically',
#  'faithless',
#  'specials',
#  'pakeza',
#  'womanizer',
#  'comin',
#  'rove',
#  'cr',
#  'piggys',
#  'excempt',
#  'scarecrows',
#  'opacity',
#  'umpire',
#  'interspersed',
#  'pitifully',
#  'mcshane',
#  'stiffing',
#  'hickenlooper',
#  'facing',
#  'boxed',
#  'undercuts',
#  'sweary',
#  'flinstones',
#  'stunners',
#  'aggressors',
#  'fracas',
#  'aleisa',
#  'blasters',
#  'haev',
#  'fluid',
#  'beggers',
#  'verisimilitude',
#  'unacted',
#  'numbing',
#  'efff',
#  'cadillacs',
#  'geli',
#  'diseased',
#  'sully',
#  'bouquet',
#  'diffring',
#  'bci',
#  'martians',
#  'overpower',
#  'dekhne',
#  'extramural',
#  'naturelle',
#  'tati',
#  'flowerchild',
#  'contradictory',
#  'tumbuan',
#  'vicious',
#  'feij',
#  'nb',
#  'burgade',
#  'propoghanda',
#  'colonial',
#  'dimming',
#  'testy',
#  'arcaica',
#  'moneyshot',
#  'sexuals',
#  'detmers',
#  'drss',
#  'hormones',
#  'incapacitates',
#  'abuses',
#  'patrizia',
#  'ps',
#  'flaring',
#  'companions',
#  'fowzi',
#  'neccessarily',
#  'cdn',
#  'maths',
#  'styalised',
#  'esoterically',
#  'steroids',
#  'ruphert',
#  'lodi',
#  'karaca',
#  'campier',
#  'antics',
#  'renaldo',
#  'dermot',
#  'areakt',
#  'cooke',
#  'digitised',
#  'shola',
#  'elbowroom',
#  'squelched',
#  'iliad',
#  'safest',
#  'szwarc',
#  'puuurfect',
#  'pulchritudinous',
#  'mattei',
#  'troubled',
#  'ringer',
#  'iowa',
#  'debased',
#  'breen',
#  'rasuk',
#  'shrewd',
#  'idea',
#  'onomatopoeic',
#  'gleeson',
#  'study',
#  'neck',
#  'personifies',
#  'mirrored',
#  'deft',
#  'love',
#  'searches',
#  'ontario',
#  'zombied',
#  'maoris',
#  'ransohoff',
#  'cacophony',
#  'charmer',
#  'unsentimentally',
#  'waldau',
#  'craig',
#  'vainly',
#  'sonzero',
#  'uncooperative',
#  'zanta',
#  'seachange',
#  'destino',
#  'rubinek',
#  'uchovsky',
#  'marino',
#  'clunkier',
#  'mcvay',
#  'artagnan',
#  'reason',
#  'sleazefest',
#  'belknap',
#  'harassing',
#  'dante',
#  'tapped',
#  'shihito',
#  'cuckold',
#  'yokozuna',
#  'sherrys',
#  'waxworks',
#  'despicableness',
#  'fending',
#  'anual',
#  'michelle',
#  'jaid',
#  'untraced',
#  'techno',
#  'mesmerising',
#  'considerations',
#  'extremis',
#  'bulgakov',
#  'unfolds',
#  'okada',
#  'delarue',
#  'kindest',
#  'defenceless',
#  'gimme',
#  'sttos',
#  'jez',
#  'larrazabal',
#  'wiring',
#  'operational',
#  'etherything',
#  'encompassed',
#  'hwy',
#  'jock',
#  'ryder',
#  'sparkles',
#  'has',
#  'lost',
#  'spell',
#  'immediately',
#  'overseer',
#  'bucsemi',
#  'djs',
#  'alongwith',
#  'gesturing',
#  'mochcinno',
#  'reso',
#  'toliet',
#  'erroneous',
#  'kristevian',
#  'ji',
#  'defectives',
#  'neecessary',
#  'contortions',
#  'lords',
#  ...}

# %% [markdown]
# 运行下方代码框，查看词汇表大小，如果一切顺利，代码输出的结果将是 **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# 观察下图，图中包括了你将在这个 notebook 里创建的神经网络的各层，其中，`layer_0` 是输入层，`layer_1`是隐藏层，`layer_2` 是输出层。

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# ![png](output_38_0.png)
#
#
#
# **待办：** 创建一个名为 `layer_0` 的 numpy 数组，将其所有元素初始化为 0。此处函数 [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) 可派上大用场。请确保你创建的 `layer_0` 是个二维矩阵，其行数为 1，列数为 `vocab_size` 的值。

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1,len(vocab)))
layer_0
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# 运行下方代码框，结果应为 `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` 包含了词汇表里的所有单词，一项代表词汇表里的一个词，如上图所示。为了确保我们知道每个单词的索引，请运行下方代码框，创建查找表并将各单词的索引存储其中。

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
#创建一个单词索引表
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'although': 1,
#  'pullout': 2,
#  'oddities': 3,
#  'therefrom': 4,
#  'belly': 5,
#  'explodes': 6,
#  'saintliness': 7,
#  'reverted': 8,
#  'wrestled': 9,
#  'romany': 10,
#  'obtuse': 11,
#  'contemplations': 12,
#  'ventura': 13,
#  'karadzhic': 14,
#  'ron': 15,
#  'thrusted': 16,
#  'sentinels': 17,
#  'poalher': 18,
#  'tremor': 19,
#  'koi': 20,
#  'boyens': 21,
#  'tased': 22,
#  'apollo': 23,
#  'stabilize': 24,
#  'stewarts': 25,
#  'translating': 26,
#  'unthinkable': 27,
#  'lei': 28,
#  'encasing': 29,
#  'livelier': 30,
#  'brilliancy': 31,
#  'mcconnahay': 32,
#  'straitjacketed': 33,
#  'unmentionable': 34,
#  'param': 35,
#  'etat': 36,
#  'twang': 37,
#  'tastes': 38,
#  'spiritless': 39,
#  'ok': 40,
#  'boneheads': 41,
#  'stensvold': 42,
#  'representing': 43,
#  'spouses': 44,
#  'boffo': 45,
#  'bergmanesque': 46,
#  'vacuously': 47,
#  'owned': 48,
#  'reinas': 49,
#  'entombed': 50,
#  'nadia': 51,
#  'handguns': 52,
#  'ontkean': 53,
#  'estelle': 54,
#  'materializes': 55,
#  'jafar': 56,
#  'lining': 57,
#  'appliances': 58,
#  'borstein': 59,
#  'swartzenegger': 60,
#  'mdchen': 61,
#  'dolomites': 62,
#  'damages': 63,
#  'shipping': 64,
#  'heartrending': 65,
#  'resistor': 66,
#  'ophuls': 67,
#  'motorcross': 68,
#  'roland': 69,
#  'idly': 70,
#  'imaginations': 71,
#  'chancery': 72,
#  'snuggled': 73,
#  'who': 74,
#  'akhtar': 75,
#  'worries': 76,
#  'savaging': 77,
#  'reiterate': 78,
#  'segregating': 79,
#  'robust': 80,
#  'tohs': 81,
#  'settle': 82,
#  'aforementioned': 83,
#  'coveys': 84,
#  'bantam': 85,
#  'spotter': 86,
#  'meurent': 87,
#  'temporality': 88,
#  'propelling': 89,
#  'beeping': 90,
#  'coote': 91,
#  'uprosing': 92,
#  'baboushka': 93,
#  'br': 94,
#  'avery': 95,
#  'anastasia': 96,
#  'hospitals': 97,
#  'troopers': 98,
#  'refresh': 99,
#  'kanmuri': 100,
#  'mmpr': 101,
#  'suckiest': 102,
#  'tastic': 103,
#  'nausea': 104,
#  'manchurian': 105,
#  'bukvic': 106,
#  'detachment': 107,
#  'skelter': 108,
#  'jolt': 109,
#  'brits': 110,
#  'saturnine': 111,
#  'stewardesses': 112,
#  'heigel': 113,
#  'pakage': 114,
#  'soundly': 115,
#  'relabeled': 116,
#  'brd': 117,
#  'influence': 118,
#  'technologies': 119,
#  'depress': 120,
#  'libertine': 121,
#  'nantes': 122,
#  'nicodemus': 123,
#  'lacks': 124,
#  'leadenly': 125,
#  'hms': 126,
#  'doel': 127,
#  'tykes': 128,
#  'bled': 129,
#  'chamberlin': 130,
#  'tumour': 131,
#  'beckinsales': 132,
#  'mran': 133,
#  'bottle': 134,
#  'tridev': 135,
#  'plently': 136,
#  'figg': 137,
#  'weekly': 138,
#  'crumbled': 139,
#  'cemented': 140,
#  'vamps': 141,
#  'woof': 142,
#  'metin': 143,
#  'whotta': 144,
#  'rabified': 145,
#  'incinerator': 146,
#  'wannabes': 147,
#  'exciter': 148,
#  'sabers': 149,
#  'frisk': 150,
#  'audiard': 151,
#  'scates': 152,
#  'rainn': 153,
#  'compatriots': 154,
#  'regimens': 155,
#  'tandy': 156,
#  'feasibly': 157,
#  'dulling': 158,
#  'gratingly': 159,
#  'illusions': 160,
#  'demons': 161,
#  'saalistajat': 162,
#  'pappas': 163,
#  'sashays': 164,
#  'induced': 165,
#  'truax': 166,
#  'kalama': 167,
#  'stethoscope': 168,
#  'scarfs': 169,
#  'coorain': 170,
#  'evidenced': 171,
#  'sopisticated': 172,
#  'thorstenson': 173,
#  'soar': 174,
#  'decoder': 175,
#  'willing': 176,
#  'ambient': 177,
#  'kiera': 178,
#  'r': 179,
#  'husbands': 180,
#  'burr': 181,
#  'proby': 182,
#  'deodato': 183,
#  'relationships': 184,
#  'lepage': 185,
#  'italianised': 186,
#  'cinemademerde': 187,
#  'dodgerdude': 188,
#  'nike': 189,
#  'perceval': 190,
#  'ardh': 191,
#  'believability': 192,
#  'erschbamer': 193,
#  'er': 194,
#  'lala': 195,
#  'lacrosse': 196,
#  'beirut': 197,
#  'horrified': 198,
#  'gained': 199,
#  'benvolio': 200,
#  'ponder': 201,
#  'nozzle': 202,
#  'snowbell': 203,
#  'hampered': 204,
#  'zimmerman': 205,
#  'carolingians': 206,
#  'kinetics': 207,
#  'facility': 208,
#  'kitted': 209,
#  'zarustica': 210,
#  'missions': 211,
#  'lawns': 212,
#  'barbarellish': 213,
#  'retiree': 214,
#  'sacrilage': 215,
#  'storyboard': 216,
#  'blankfield': 217,
#  'granger': 218,
#  'nutzo': 219,
#  'cataloguing': 220,
#  'joliet': 221,
#  'tristran': 222,
#  'beaters': 223,
#  'muerte': 224,
#  'marcel': 225,
#  'palatial': 226,
#  'fiancs': 227,
#  'bams': 228,
#  'graininess': 229,
#  'muldaur': 230,
#  'burstyn': 231,
#  'conspicious': 232,
#  'abruptness': 233,
#  'qualitys': 234,
#  'multiculturalism': 235,
#  'physco': 236,
#  'necron': 237,
#  'oracles': 238,
#  'fortuitous': 239,
#  'weeps': 240,
#  'callahan': 241,
#  'likeliness': 242,
#  'redistribute': 243,
#  'snatchers': 244,
#  'drawbacks': 245,
#  'devotional': 246,
#  'overview': 247,
#  'supertroopers': 248,
#  'leeringly': 249,
#  'dryer': 250,
#  'promotes': 251,
#  'runner': 252,
#  'goldie': 253,
#  'aaghh': 254,
#  'vicitm': 255,
#  'leprous': 256,
#  'dahl': 257,
#  'sanguisuga': 258,
#  'gaolers': 259,
#  'granzow': 260,
#  'vindictively': 261,
#  'jurassic': 262,
#  'insupportable': 263,
#  'assign': 264,
#  'dethaw': 265,
#  'deconstructed': 266,
#  'nnette': 267,
#  'laroche': 268,
#  'pyke': 269,
#  'aprox': 270,
#  'manouvres': 271,
#  'tool': 272,
#  'sobs': 273,
#  'chepart': 274,
#  'kitley': 275,
#  'dia': 276,
#  'stripped': 277,
#  'impossibility': 278,
#  'chappu': 279,
#  'smarmiest': 280,
#  'pollutes': 281,
#  'bavarian': 282,
#  'followups': 283,
#  'blystone': 284,
#  'mimetic': 285,
#  'rostov': 286,
#  'kappor': 287,
#  'demystifying': 288,
#  'emanating': 289,
#  'dish': 290,
#  'taxing': 291,
#  'intoxicating': 292,
#  'pumped': 293,
#  'loggins': 294,
#  'resets': 295,
#  'azema': 296,
#  'nose': 297,
#  'pancreatitis': 298,
#  'beech': 299,
#  'sogo': 300,
#  'tyranosaurous': 301,
#  'leitmotivs': 302,
#  'allures': 303,
#  'todd': 304,
#  'monument': 305,
#  'admarible': 306,
#  'macanally': 307,
#  'strutts': 308,
#  'churchill': 309,
#  'trotting': 310,
#  'fightm': 311,
#  'aussies': 312,
#  'pasa': 313,
#  'criminology': 314,
#  'marco': 315,
#  'nevada': 316,
#  'prescreening': 317,
#  'inebriation': 318,
#  'starringsean': 319,
#  'connecticute': 320,
#  'scorned': 321,
#  'mancori': 322,
#  'sensitivity': 323,
#  'anger': 324,
#  'decade': 325,
#  'spooky': 326,
#  'grieg': 327,
#  'dropping': 328,
#  'supposibly': 329,
#  'lavishly': 330,
#  'matriculates': 331,
#  'hadj': 332,
#  'raghubir': 333,
#  'alleging': 334,
#  'convincedness': 335,
#  'sedative': 336,
#  'whilhelm': 337,
#  'accessability': 338,
#  'tormento': 339,
#  'shroyer': 340,
#  'sillier': 341,
#  'orb': 342,
#  'katy': 343,
#  'koteas': 344,
#  'hellbound': 345,
#  'settlefor': 346,
#  'offhand': 347,
#  'innumerable': 348,
#  'fascinatingly': 349,
#  'sharpshooter': 350,
#  'hentai': 351,
#  'dimmed': 352,
#  'continental': 353,
#  'vasectomies': 354,
#  'directorial': 355,
#  'your': 356,
#  'chess': 357,
#  'hautefeuille': 358,
#  'hatley': 359,
#  'netherlands': 360,
#  'oland': 361,
#  'bell': 362,
#  'blakes': 363,
#  'fathoming': 364,
#  'padm': 365,
#  'environs': 366,
#  'monopolies': 367,
#  'guillaumme': 368,
#  'draza': 369,
#  'quasirealistic': 370,
#  'electricity': 371,
#  'unjust': 372,
#  'checkpoints': 373,
#  'boricua': 374,
#  'talia': 375,
#  'conditioning': 376,
#  'anupamji': 377,
#  'consecutive': 378,
#  'broker': 379,
#  'dantesque': 380,
#  'unaccomplished': 381,
#  'eisenmann': 382,
#  'undead': 383,
#  'pasqal': 384,
#  'pascow': 385,
#  'schlettow': 386,
#  'narration': 387,
#  'bedfellows': 388,
#  'differential': 389,
#  'habituation': 390,
#  'collective': 391,
#  'roubaix': 392,
#  'efenstor': 393,
#  'springing': 394,
#  'lebrock': 395,
#  'cheswick': 396,
#  'grinding': 397,
#  'chortle': 398,
#  'delightful': 399,
#  'terry': 400,
#  'ozkan': 401,
#  'watershed': 402,
#  'liqueur': 403,
#  'dekhiye': 404,
#  'favoritism': 405,
#  'mobocracy': 406,
#  'eccelston': 407,
#  'hallelujah': 408,
#  'joxs': 409,
#  'booke': 410,
#  'euthenased': 411,
#  'asphalt': 412,
#  'argentina': 413,
#  'bureacracy': 414,
#  'railroads': 415,
#  'merlet': 416,
#  'showcased': 417,
#  'diary': 418,
#  'sympathized': 419,
#  'chiani': 420,
#  'rug': 421,
#  'paint': 422,
#  'contributers': 423,
#  'readiness': 424,
#  'recieves': 425,
#  'pursuing': 426,
#  'radiating': 427,
#  'dramatizing': 428,
#  'sods': 429,
#  'gundam': 430,
#  'masterpeice': 431,
#  'uhs': 432,
#  'storied': 433,
#  'thc': 434,
#  'ripping': 435,
#  'oops': 436,
#  'zorba': 437,
#  'gaga': 438,
#  'nappy': 439,
#  'holey': 440,
#  'pooling': 441,
#  'stumped': 442,
#  'hotly': 443,
#  'doodo': 444,
#  'chonopolisians': 445,
#  'littlefield': 446,
#  'edition': 447,
#  'cardboard': 448,
#  'ebay': 449,
#  'donnacha': 450,
#  'unaccpectable': 451,
#  'fluke': 452,
#  'neutering': 453,
#  'eeks': 454,
#  'evocatively': 455,
#  'culinary': 456,
#  'duuum': 457,
#  'adherents': 458,
#  'jimi': 459,
#  'cliques': 460,
#  'overstyling': 461,
#  'radiohead': 462,
#  'formulatic': 463,
#  'shock': 464,
#  'hammish': 465,
#  'sunnydale': 466,
#  'fortunate': 467,
#  'kayak': 468,
#  'unwarily': 469,
#  'hypothermia': 470,
#  'validity': 471,
#  'confusion': 472,
#  'nope': 473,
#  'bedtime': 474,
#  'rustle': 475,
#  'rambunctious': 476,
#  'inexcusably': 477,
#  'sprinkled': 478,
#  'matt': 479,
#  'latecomer': 480,
#  'fratboy': 481,
#  'circumcision': 482,
#  'shampoo': 483,
#  'tempo': 484,
#  'calleia': 485,
#  'boars': 486,
#  'wresting': 487,
#  'rakastin': 488,
#  'marafon': 489,
#  'harrisonfirst': 490,
#  'shoddiest': 491,
#  'mall': 492,
#  'utility': 493,
#  'chinatown': 494,
#  'vileness': 495,
#  'recriminations': 496,
#  'solidity': 497,
#  'tersteeghe': 498,
#  'liquefied': 499,
#  'incentive': 500,
#  'sorts': 501,
#  'meandering': 502,
#  'shibasaki': 503,
#  'tusk': 504,
#  'duddy': 505,
#  'bewilder': 506,
#  'lubricated': 507,
#  'gear': 508,
#  'snoopy': 509,
#  'fight': 510,
#  'inexplicable': 511,
#  'tazmanian': 512,
#  'redstacey': 513,
#  'alyce': 514,
#  'seger': 515,
#  'douce': 516,
#  'dancehall': 517,
#  'devil': 518,
#  'flair': 519,
#  'misfortune': 520,
#  'myeres': 521,
#  'gitai': 522,
#  'maze': 523,
#  'inconsistancies': 524,
#  'citta': 525,
#  'identical': 526,
#  'durable': 527,
#  'vaxham': 528,
#  'anglo': 529,
#  'bragging': 530,
#  'giegud': 531,
#  'flirting': 532,
#  'mesquida': 533,
#  'dip': 534,
#  'crowell': 535,
#  'noway': 536,
#  'odin': 537,
#  'daslow': 538,
#  'emitting': 539,
#  'stoppage': 540,
#  'hedged': 541,
#  'antartic': 542,
#  'lasciviousness': 543,
#  'persecution': 544,
#  'fanshawe': 545,
#  'strobing': 546,
#  'heatbreaking': 547,
#  'menace': 548,
#  'phobias': 549,
#  'hool': 550,
#  'gad': 551,
#  'mutterings': 552,
#  'poet': 553,
#  'inconsistencies': 554,
#  'nallae': 555,
#  'ratings': 556,
#  'gould': 557,
#  'thata': 558,
#  'anecdote': 559,
#  'rail': 560,
#  'depardeu': 561,
#  'rungs': 562,
#  'capulet': 563,
#  'explorer': 564,
#  'seascape': 565,
#  'employee': 566,
#  'twentysomething': 567,
#  'renal': 568,
#  'windup': 569,
#  'shellshocked': 570,
#  'clinkers': 571,
#  'diatribe': 572,
#  'cloned': 573,
#  'meatlocker': 574,
#  'auditorium': 575,
#  'revitalizes': 576,
#  'gaylord': 577,
#  'coutard': 578,
#  'bones': 579,
#  'banderas': 580,
#  'births': 581,
#  'fosse': 582,
#  'sunroof': 583,
#  'blush': 584,
#  'gordon': 585,
#  'chagrin': 586,
#  'ghostbuster': 587,
#  'celebrations': 588,
#  'fetuccini': 589,
#  'planetary': 590,
#  'rifted': 591,
#  'long': 592,
#  'scholastic': 593,
#  'adversities': 594,
#  'equidor': 595,
#  'neglect': 596,
#  'dastak': 597,
#  'gojn': 598,
#  'hires': 599,
#  'airing': 600,
#  'bunny': 601,
#  'unbelievable': 602,
#  'lang': 603,
#  'mohawk': 604,
#  'purr': 605,
#  'termites': 606,
#  'often': 607,
#  'pliant': 608,
#  'firguring': 609,
#  'evaporated': 610,
#  'fawn': 611,
#  'creepies': 612,
#  'pollinating': 613,
#  'berzier': 614,
#  'suffice': 615,
#  'manchus': 616,
#  'baltic': 617,
#  'mutinous': 618,
#  'landmines': 619,
#  'knows': 620,
#  'alekos': 621,
#  'addressing': 622,
#  'dvr': 623,
#  'matteo': 624,
#  'behold': 625,
#  'hypnosis': 626,
#  'herbie': 627,
#  'pain': 628,
#  'keanu': 629,
#  'virulently': 630,
#  'dishwater': 631,
#  'moxy': 632,
#  'dinky': 633,
#  'plywood': 634,
#  'spawned': 635,
#  'bewafaa': 636,
#  'foothold': 637,
#  'indiains': 638,
#  'elivates': 639,
#  'micheals': 640,
#  'battre': 641,
#  'gregarious': 642,
#  'yar': 643,
#  'aerodynamics': 644,
#  'nonchalant': 645,
#  'appear': 646,
#  'favreau': 647,
#  'manon': 648,
#  'waves': 649,
#  'tuvoks': 650,
#  'sensuous': 651,
#  'howes': 652,
#  'ververgaert': 653,
#  'changeling': 654,
#  'stinking': 655,
#  'humanity': 656,
#  'grapes': 657,
#  'journos': 658,
#  'beautifully': 659,
#  'reunion': 660,
#  'vocational': 661,
#  'deploys': 662,
#  'americana': 663,
#  'infighting': 664,
#  'shakesphere': 665,
#  'coupledom': 666,
#  'objectively': 667,
#  'acharya': 668,
#  'kidnapper': 669,
#  'straighten': 670,
#  'streep': 671,
#  'queries': 672,
#  'theat': 673,
#  'thirsty': 674,
#  'computeranimation': 675,
#  'textural': 676,
#  'coonskin': 677,
#  'trio': 678,
#  'scouted': 679,
#  'referendum': 680,
#  'cuticle': 681,
#  'paperwork': 682,
#  'forewarns': 683,
#  'alchoholic': 684,
#  'tyrants': 685,
#  'saucy': 686,
#  'mallrats': 687,
#  'zigfield': 688,
#  'jeanane': 689,
#  'thinking': 690,
#  'realized': 691,
#  'conran': 692,
#  'semple': 693,
#  'masculin': 694,
#  'dramatize': 695,
#  'meddlesome': 696,
#  'appreciative': 697,
#  'kabaree': 698,
#  'constitutionally': 699,
#  'bookman': 700,
#  'hystericalness': 701,
#  'gospel': 702,
#  'heinkel': 703,
#  'tomcat': 704,
#  'klugman': 705,
#  'gymnast': 706,
#  'wilco': 707,
#  'waterstone': 708,
#  'ooohhh': 709,
#  'realityshowlike': 710,
#  'plugs': 711,
#  'bickering': 712,
#  'drudge': 713,
#  'demands': 714,
#  'perplexities': 715,
#  'dumbs': 716,
#  'nomadic': 717,
#  'slickers': 718,
#  'suleiman': 719,
#  'susi': 720,
#  'moshpit': 721,
#  'jitters': 722,
#  'sickness': 723,
#  'wazoo': 724,
#  'norse': 725,
#  'shillings': 726,
#  'montazuma': 727,
#  'shaloub': 728,
#  'gretel': 729,
#  'expanding': 730,
#  'majors': 731,
#  'outdated': 732,
#  'coool': 733,
#  'repellent': 734,
#  'starlet': 735,
#  'broader': 736,
#  'rockies': 737,
#  'kernel': 738,
#  'initial': 739,
#  'earths': 740,
#  'eschelons': 741,
#  'rebe': 742,
#  'jungle': 743,
#  'creasey': 744,
#  'bigg': 745,
#  'encapsulated': 746,
#  'deadbeat': 747,
#  'bangster': 748,
#  'wounds': 749,
#  'fixation': 750,
#  'password': 751,
#  'alicianne': 752,
#  'cccc': 753,
#  'ranches': 754,
#  'handless': 755,
#  'nosedive': 756,
#  'kearn': 757,
#  'samwise': 758,
#  'montmirail': 759,
#  'unachieving': 760,
#  'depriving': 761,
#  'disrobes': 762,
#  'smooshed': 763,
#  'molemen': 764,
#  'chessy': 765,
#  'anyhows': 766,
#  'flourishing': 767,
#  'iciness': 768,
#  'referat': 769,
#  'gruff': 770,
#  'argufying': 771,
#  'anno': 772,
#  'stows': 773,
#  'pados': 774,
#  'weaponry': 775,
#  'harvester': 776,
#  'modifies': 777,
#  'smelly': 778,
#  'unseemly': 779,
#  'cheddar': 780,
#  'overfed': 781,
#  'erupts': 782,
#  'fairly': 783,
#  'algrant': 784,
#  'jiggle': 785,
#  'shriver': 786,
#  'caution': 787,
#  'lanka': 788,
#  'darius': 789,
#  'nettie': 790,
#  'invesment': 791,
#  'also': 792,
#  'harf': 793,
#  'conscientious': 794,
#  'mysteries': 795,
#  'cheapen': 796,
#  'bergin': 797,
#  'reservedly': 798,
#  'hellishly': 799,
#  'slashing': 800,
#  'crasser': 801,
#  'handwriting': 802,
#  'unidentified': 803,
#  'advani': 804,
#  'ethnographer': 805,
#  'pontificating': 806,
#  'authentically': 807,
#  'faithless': 808,
#  'specials': 809,
#  'pakeza': 810,
#  'womanizer': 811,
#  'comin': 812,
#  'rove': 813,
#  'cr': 814,
#  'piggys': 815,
#  'excempt': 816,
#  'scarecrows': 817,
#  'opacity': 818,
#  'umpire': 819,
#  'interspersed': 820,
#  'pitifully': 821,
#  'mcshane': 822,
#  'stiffing': 823,
#  'hickenlooper': 824,
#  'facing': 825,
#  'boxed': 826,
#  'undercuts': 827,
#  'sweary': 828,
#  'flinstones': 829,
#  'stunners': 830,
#  'aggressors': 831,
#  'fracas': 832,
#  'aleisa': 833,
#  'blasters': 834,
#  'haev': 835,
#  'fluid': 836,
#  'beggers': 837,
#  'verisimilitude': 838,
#  'unacted': 839,
#  'numbing': 840,
#  'efff': 841,
#  'cadillacs': 842,
#  'geli': 843,
#  'diseased': 844,
#  'sully': 845,
#  'bouquet': 846,
#  'diffring': 847,
#  'bci': 848,
#  'martians': 849,
#  'overpower': 850,
#  'dekhne': 851,
#  'extramural': 852,
#  'naturelle': 853,
#  'tati': 854,
#  'flowerchild': 855,
#  'contradictory': 856,
#  'tumbuan': 857,
#  'vicious': 858,
#  'feij': 859,
#  'nb': 860,
#  'burgade': 861,
#  'propoghanda': 862,
#  'colonial': 863,
#  'dimming': 864,
#  'testy': 865,
#  'arcaica': 866,
#  'moneyshot': 867,
#  'sexuals': 868,
#  'detmers': 869,
#  'drss': 870,
#  'hormones': 871,
#  'incapacitates': 872,
#  'abuses': 873,
#  'patrizia': 874,
#  'ps': 875,
#  'flaring': 876,
#  'companions': 877,
#  'fowzi': 878,
#  'neccessarily': 879,
#  'cdn': 880,
#  'maths': 881,
#  'styalised': 882,
#  'esoterically': 883,
#  'steroids': 884,
#  'ruphert': 885,
#  'lodi': 886,
#  'karaca': 887,
#  'campier': 888,
#  'antics': 889,
#  'renaldo': 890,
#  'dermot': 891,
#  'areakt': 892,
#  'cooke': 893,
#  'digitised': 894,
#  'shola': 895,
#  'elbowroom': 896,
#  'squelched': 897,
#  'iliad': 898,
#  'safest': 899,
#  'szwarc': 900,
#  'puuurfect': 901,
#  'pulchritudinous': 902,
#  'mattei': 903,
#  'troubled': 904,
#  'ringer': 905,
#  'iowa': 906,
#  'debased': 907,
#  'breen': 908,
#  'rasuk': 909,
#  'shrewd': 910,
#  'idea': 911,
#  'onomatopoeic': 912,
#  'gleeson': 913,
#  'study': 914,
#  'neck': 915,
#  'personifies': 916,
#  'mirrored': 917,
#  'deft': 918,
#  'love': 919,
#  'searches': 920,
#  'ontario': 921,
#  'zombied': 922,
#  'maoris': 923,
#  'ransohoff': 924,
#  'cacophony': 925,
#  'charmer': 926,
#  'unsentimentally': 927,
#  'waldau': 928,
#  'craig': 929,
#  'vainly': 930,
#  'sonzero': 931,
#  'uncooperative': 932,
#  'zanta': 933,
#  'seachange': 934,
#  'destino': 935,
#  'rubinek': 936,
#  'uchovsky': 937,
#  'marino': 938,
#  'clunkier': 939,
#  'mcvay': 940,
#  'artagnan': 941,
#  'reason': 942,
#  'sleazefest': 943,
#  'belknap': 944,
#  'harassing': 945,
#  'dante': 946,
#  'tapped': 947,
#  'shihito': 948,
#  'cuckold': 949,
#  'yokozuna': 950,
#  'sherrys': 951,
#  'waxworks': 952,
#  'despicableness': 953,
#  'fending': 954,
#  'anual': 955,
#  'michelle': 956,
#  'jaid': 957,
#  'untraced': 958,
#  'techno': 959,
#  'mesmerising': 960,
#  'considerations': 961,
#  'extremis': 962,
#  'bulgakov': 963,
#  'unfolds': 964,
#  'okada': 965,
#  'delarue': 966,
#  'kindest': 967,
#  'defenceless': 968,
#  'gimme': 969,
#  'sttos': 970,
#  'jez': 971,
#  'larrazabal': 972,
#  'wiring': 973,
#  'operational': 974,
#  'etherything': 975,
#  'encompassed': 976,
#  'hwy': 977,
#  'jock': 978,
#  'ryder': 979,
#  'sparkles': 980,
#  'has': 981,
#  'lost': 982,
#  'spell': 983,
#  'immediately': 984,
#  'overseer': 985,
#  'bucsemi': 986,
#  'djs': 987,
#  'alongwith': 988,
#  'gesturing': 989,
#  'mochcinno': 990,
#  'reso': 991,
#  'toliet': 992,
#  'erroneous': 993,
#  'kristevian': 994,
#  'ji': 995,
#  'defectives': 996,
#  'neecessary': 997,
#  'contortions': 998,
#  'lords': 999,
#  ...}

# %% [markdown]
# **待办:**  实现函数 `update_input_layer`，使该函数统计每个单词出现在给定评论里的次数，并将统计结果存入 `layer_0` 相应的索引下。

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    修改全局layer_0以表示评论的矢量形式。     
    给定索引的layer_0元素应表示     
    给定单词在评论中出现了多少次
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    for word in review.split(' '):
        word_index = word2index[word]
#         print(word_index)
#         layer_0[:,word_index] += 1
        layer_0[0,word_index] += 1

# %% [markdown]
# 运行下方代码框，测试用第一条评论更新输入层的效果。此处所赋索引可能与解决方案中的不同，但你应该也能看到 `layer_0` 中出现了一些非零数值。

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %% [markdown]
# **待办：** 实现函数 `get_target_for_labels`，使其根据给定标签是 `NEGATIVE` （负面）还是 `POSITIVE` （正面）返回 `0` 或 `1`。

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    if (label == 'POSITIVE'):
        return 1
    else:
        return 0

# %% [markdown]
# 运行下方两个代码框，结果应分别输出 `'POSITIVE'` 和 `1`。

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# 运行下方两个代码框，结果应分别输出 `'NEGATIVE'` 和 `0`。

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
#  **高效率：**
#  * 当在创建类似于`layer_0`这样的变量时，尽量不要为数据分配全新的向量。
#  * 没有预生成完整的数据集。

# %% [markdown]
# # 项目 2 到此结束。
# ## 请进入下一个视频，观看 Andrew 的解决方案，然后继续学习下一课。
#
# # 项目 3：创建神经网络<a id='project_3'></a>
#
# **待办：** 此处使用了类 `SentimentNetork` 的框架，请实现代码里所有标有 `TODO` 的待办事项，具体操作内容如下：
# - 创建一个基本的神经网络，就像你在之前的课程和项目 1 中看到的一样，该网络应具备一个输入层、一个隐藏层和一个输出层。
# - 请**不要**在隐藏层中添加非线性元素，也就是说，请不要用激活函数计算隐藏层的输出。
# - 利用本 notebook 前面的代码来创建训练数据（请见代码中的 `TODO` 事项）
# - 实现函数 `pre_process_data`，为训练数据生成函数创建词汇表
# - 确保 `train` 会对整个语料库进行训练
#
# ### 如有需要，请
# - 重看以前的优达学城课程
# - 查阅 [《深度学习详解》](https://www.manning.com/books/grokking-deep-learning)的第 3-5 章 - (请进入课室查看优惠码)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        # TODO: populate review_vocab with all of the words in the given reviews 
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
        # Convert the vocabulary set to a list so we can access words via indices 
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        for label in labels:
            label_vocab.add(label)
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook 

        for i,word in enumerate(self.review_vocab):
            self.word2index[word] = i
            
        # Create a dictionary of labels mapped to index positions 
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead 
        for j,label in enumerate(self.label_vocab):
            self.label2index[label] = j
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes, self.hidden_nodes))
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero 1 x input_nodes，
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"

        # clear out previous state by resetting the layer to be all 0s
        self.layer_0 *= 0

        # TODO: count how many times each word is used in the given review and store the results in layer_0 
        for word in review.split(' '):

            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        if (label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures 
        return 1 / (1+np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        return output * (1-output)

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            #input layer
            self.update_input_layer(review)
            
            #hidden layer 输出
            layer_1 = self.layer_0.dot(self.weights_0_1)
            
            #output layer 输出
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            #  Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            # 由于此处是线性的，所以不用进行斜率调整
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# 运行下方代码框，创建 `SentimentNetwork`，使之训练除最后一千条评论之外的所有评论（那一千条评论将用于测试），此处我们使用的学习率为 `0.1`。

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# 运行下方代码框，用最后一千条评论测试网络的性能（即我们不用作训练集的那部分评论）。
#
# **我们还没有训练模型，所以模型只是单纯地在猜测，鉴于可选的值只有两个，因此准确率应该在   50% 左右。**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:13.6% Speed(reviews/sec):745.1 #Correct:69 #Tested:137 Testing Accuracy:50.3%
# Progress:27.9% Speed(reviews/sec):754.0 #Correct:140 #Tested:280 Testing Accuracy:50.0%
# Progress:41.9% Speed(reviews/sec):750.2 #Correct:210 #Tested:420 Testing Accuracy:50.0%
# Progress:54.0% Speed(reviews/sec):725.7 #Correct:271 #Tested:541 Testing Accuracy:50.0%
# Progress:67.1% Speed(reviews/sec):719.1 #Correct:336 #Tested:672 Testing Accuracy:50.0%
# Progress:80.8% Speed(reviews/sec):721.3 #Correct:405 #Tested:809 Testing Accuracy:50.0%
# Progress:93.4% Speed(reviews/sec):714.8 #Correct:468 #Tested:935 Testing Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):713.9 #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %% [markdown]
# 运行下方代码框，开始训练网络。训练时，代码会不断输出模型的准确性，以便你观察模型的训练效果。

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):96.67 #Correct:1251 #Trained:2501 Training Accuracy:50.0%
# Progress:18.0% Speed(reviews/sec):95.20 #Correct:2166 #Trained:4332 Training Accuracy:50.0%
# -----------------------------------------------------------------
# KeyboardInterrupt               Traceback (most recent call last)
# <ipython-input-42-a5b7efd2dc8f> in <module>
# ----> 1 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-39-0dfb041b74c9> in train(self, training_reviews, training_labels)
#     176             # Update the weights
#     177             self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 178             self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     179
#     180             # TODO: Keep track of correct predictions. To determine if the prediction was
#
# KeyboardInterrupt:

# %% [markdown]
# 很可能训练效果并不好，部分原因可能在于学习率太高了。运行下方代码框，将学习率调小为 `0.01`，重建并重新训练网络。

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):95.18 #Correct:1248 #Trained:2501 Training Accuracy:49.9%
# Progress:20.8% Speed(reviews/sec):94.67 #Correct:2498 #Trained:5001 Training Accuracy:49.9%
# Progress:30.4% Speed(reviews/sec):85.15 #Correct:3648 #Trained:7300 Training Accuracy:49.9%
# -----------------------------------------------------------------
# KeyboardInterrupt               Traceback (most recent call last)
# <ipython-input-43-ae7da216e940> in <module>
#       1 mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
# ----> 2 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-39-0dfb041b74c9> in train(self, training_reviews, training_labels)
#     176             # Update the weights
#     177             self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 178             self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     179
#     180             # TODO: Keep track of correct predictions. To determine if the prediction was
#
# KeyboardInterrupt:

# %% [markdown]
# 可能效果还是不好。运行下方代码框，再次将学习率调小为 `0.001`，再次重建并重新训练网络。

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):57.87 #Correct:1258 #Trained:2501 Training Accuracy:50.2%
# Progress:20.8% Speed(reviews/sec):55.16 #Correct:2522 #Trained:5001 Training Accuracy:50.4%
# Progress:31.2% Speed(reviews/sec):55.02 #Correct:3782 #Trained:7501 Training Accuracy:50.4%
# Progress:41.6% Speed(reviews/sec):54.78 #Correct:5198 #Trained:10001 Training Accuracy:51.9%
# Progress:52.0% Speed(reviews/sec):54.16 #Correct:6694 #Trained:12501 Training Accuracy:53.5%
# Progress:62.5% Speed(reviews/sec):54.55 #Correct:8247 #Trained:15001 Training Accuracy:54.9%
# Progress:72.9% Speed(reviews/sec):54.83 #Correct:9781 #Trained:17501 Training Accuracy:55.8%
# Progress:75.6% Speed(reviews/sec):54.93 #Correct:10212 #Trained:18157 Training Accuracy:56.2%
# -----------------------------------------------------------------
# KeyboardInterrupt               Traceback (most recent call last)
# <ipython-input-44-00cb6eecd69a> in <module>
#       1 mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
# ----> 2 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-39-0dfb041b74c9> in train(self, training_reviews, training_labels)
#     176             # Update the weights
#     177             self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 178             self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     179
#     180             # TODO: Keep track of correct predictions. To determine if the prediction was
#
# KeyboardInterrupt:

# %% [markdown]
# 当学习率为 `0.001` 时，网络应该终于开始随着训练进行改进了，虽然效果还是不尽人意，但起码说明了这个解决方案是可行的。我们会在下一课进一步改进这个网络。
#
# # 项目 3 到此结束。
# ## 请进入下一个视频，观看  Andrew 的解决方案，然后继续学习下一课。
#
# # 理解神经噪声<a id='lesson_4'></a>
#
# 下方代码框包含了 Andrew 在下一个视频里使用的代码，因此你无须手动输入，只需运行代码框，即可跟着视频运行代码。。

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
word2index
# Out:
# {'': 0,
#  'although': 1,
#  'pullout': 2,
#  'oddities': 3,
#  'therefrom': 4,
#  'belly': 5,
#  'explodes': 6,
#  'saintliness': 7,
#  'reverted': 8,
#  'wrestled': 9,
#  'romany': 10,
#  'obtuse': 11,
#  'contemplations': 12,
#  'ventura': 13,
#  'karadzhic': 14,
#  'ron': 15,
#  'thrusted': 16,
#  'sentinels': 17,
#  'poalher': 18,
#  'tremor': 19,
#  'koi': 20,
#  'boyens': 21,
#  'tased': 22,
#  'apollo': 23,
#  'stabilize': 24,
#  'stewarts': 25,
#  'translating': 26,
#  'unthinkable': 27,
#  'lei': 28,
#  'encasing': 29,
#  'livelier': 30,
#  'brilliancy': 31,
#  'mcconnahay': 32,
#  'straitjacketed': 33,
#  'unmentionable': 34,
#  'param': 35,
#  'etat': 36,
#  'twang': 37,
#  'tastes': 38,
#  'spiritless': 39,
#  'ok': 40,
#  'boneheads': 41,
#  'stensvold': 42,
#  'representing': 43,
#  'spouses': 44,
#  'boffo': 45,
#  'bergmanesque': 46,
#  'vacuously': 47,
#  'owned': 48,
#  'reinas': 49,
#  'entombed': 50,
#  'nadia': 51,
#  'handguns': 52,
#  'ontkean': 53,
#  'estelle': 54,
#  'materializes': 55,
#  'jafar': 56,
#  'lining': 57,
#  'appliances': 58,
#  'borstein': 59,
#  'swartzenegger': 60,
#  'mdchen': 61,
#  'dolomites': 62,
#  'damages': 63,
#  'shipping': 64,
#  'heartrending': 65,
#  'resistor': 66,
#  'ophuls': 67,
#  'motorcross': 68,
#  'roland': 69,
#  'idly': 70,
#  'imaginations': 71,
#  'chancery': 72,
#  'snuggled': 73,
#  'who': 74,
#  'akhtar': 75,
#  'worries': 76,
#  'savaging': 77,
#  'reiterate': 78,
#  'segregating': 79,
#  'robust': 80,
#  'tohs': 81,
#  'settle': 82,
#  'aforementioned': 83,
#  'coveys': 84,
#  'bantam': 85,
#  'spotter': 86,
#  'meurent': 87,
#  'temporality': 88,
#  'propelling': 89,
#  'beeping': 90,
#  'coote': 91,
#  'uprosing': 92,
#  'baboushka': 93,
#  'br': 94,
#  'avery': 95,
#  'anastasia': 96,
#  'hospitals': 97,
#  'troopers': 98,
#  'refresh': 99,
#  'kanmuri': 100,
#  'mmpr': 101,
#  'suckiest': 102,
#  'tastic': 103,
#  'nausea': 104,
#  'manchurian': 105,
#  'bukvic': 106,
#  'detachment': 107,
#  'skelter': 108,
#  'jolt': 109,
#  'brits': 110,
#  'saturnine': 111,
#  'stewardesses': 112,
#  'heigel': 113,
#  'pakage': 114,
#  'soundly': 115,
#  'relabeled': 116,
#  'brd': 117,
#  'influence': 118,
#  'technologies': 119,
#  'depress': 120,
#  'libertine': 121,
#  'nantes': 122,
#  'nicodemus': 123,
#  'lacks': 124,
#  'leadenly': 125,
#  'hms': 126,
#  'doel': 127,
#  'tykes': 128,
#  'bled': 129,
#  'chamberlin': 130,
#  'tumour': 131,
#  'beckinsales': 132,
#  'mran': 133,
#  'bottle': 134,
#  'tridev': 135,
#  'plently': 136,
#  'figg': 137,
#  'weekly': 138,
#  'crumbled': 139,
#  'cemented': 140,
#  'vamps': 141,
#  'woof': 142,
#  'metin': 143,
#  'whotta': 144,
#  'rabified': 145,
#  'incinerator': 146,
#  'wannabes': 147,
#  'exciter': 148,
#  'sabers': 149,
#  'frisk': 150,
#  'audiard': 151,
#  'scates': 152,
#  'rainn': 153,
#  'compatriots': 154,
#  'regimens': 155,
#  'tandy': 156,
#  'feasibly': 157,
#  'dulling': 158,
#  'gratingly': 159,
#  'illusions': 160,
#  'demons': 161,
#  'saalistajat': 162,
#  'pappas': 163,
#  'sashays': 164,
#  'induced': 165,
#  'truax': 166,
#  'kalama': 167,
#  'stethoscope': 168,
#  'scarfs': 169,
#  'coorain': 170,
#  'evidenced': 171,
#  'sopisticated': 172,
#  'thorstenson': 173,
#  'soar': 174,
#  'decoder': 175,
#  'willing': 176,
#  'ambient': 177,
#  'kiera': 178,
#  'r': 179,
#  'husbands': 180,
#  'burr': 181,
#  'proby': 182,
#  'deodato': 183,
#  'relationships': 184,
#  'lepage': 185,
#  'italianised': 186,
#  'cinemademerde': 187,
#  'dodgerdude': 188,
#  'nike': 189,
#  'perceval': 190,
#  'ardh': 191,
#  'believability': 192,
#  'erschbamer': 193,
#  'er': 194,
#  'lala': 195,
#  'lacrosse': 196,
#  'beirut': 197,
#  'horrified': 198,
#  'gained': 199,
#  'benvolio': 200,
#  'ponder': 201,
#  'nozzle': 202,
#  'snowbell': 203,
#  'hampered': 204,
#  'zimmerman': 205,
#  'carolingians': 206,
#  'kinetics': 207,
#  'facility': 208,
#  'kitted': 209,
#  'zarustica': 210,
#  'missions': 211,
#  'lawns': 212,
#  'barbarellish': 213,
#  'retiree': 214,
#  'sacrilage': 215,
#  'storyboard': 216,
#  'blankfield': 217,
#  'granger': 218,
#  'nutzo': 219,
#  'cataloguing': 220,
#  'joliet': 221,
#  'tristran': 222,
#  'beaters': 223,
#  'muerte': 224,
#  'marcel': 225,
#  'palatial': 226,
#  'fiancs': 227,
#  'bams': 228,
#  'graininess': 229,
#  'muldaur': 230,
#  'burstyn': 231,
#  'conspicious': 232,
#  'abruptness': 233,
#  'qualitys': 234,
#  'multiculturalism': 235,
#  'physco': 236,
#  'necron': 237,
#  'oracles': 238,
#  'fortuitous': 239,
#  'weeps': 240,
#  'callahan': 241,
#  'likeliness': 242,
#  'redistribute': 243,
#  'snatchers': 244,
#  'drawbacks': 245,
#  'devotional': 246,
#  'overview': 247,
#  'supertroopers': 248,
#  'leeringly': 249,
#  'dryer': 250,
#  'promotes': 251,
#  'runner': 252,
#  'goldie': 253,
#  'aaghh': 254,
#  'vicitm': 255,
#  'leprous': 256,
#  'dahl': 257,
#  'sanguisuga': 258,
#  'gaolers': 259,
#  'granzow': 260,
#  'vindictively': 261,
#  'jurassic': 262,
#  'insupportable': 263,
#  'assign': 264,
#  'dethaw': 265,
#  'deconstructed': 266,
#  'nnette': 267,
#  'laroche': 268,
#  'pyke': 269,
#  'aprox': 270,
#  'manouvres': 271,
#  'tool': 272,
#  'sobs': 273,
#  'chepart': 274,
#  'kitley': 275,
#  'dia': 276,
#  'stripped': 277,
#  'impossibility': 278,
#  'chappu': 279,
#  'smarmiest': 280,
#  'pollutes': 281,
#  'bavarian': 282,
#  'followups': 283,
#  'blystone': 284,
#  'mimetic': 285,
#  'rostov': 286,
#  'kappor': 287,
#  'demystifying': 288,
#  'emanating': 289,
#  'dish': 290,
#  'taxing': 291,
#  'intoxicating': 292,
#  'pumped': 293,
#  'loggins': 294,
#  'resets': 295,
#  'azema': 296,
#  'nose': 297,
#  'pancreatitis': 298,
#  'beech': 299,
#  'sogo': 300,
#  'tyranosaurous': 301,
#  'leitmotivs': 302,
#  'allures': 303,
#  'todd': 304,
#  'monument': 305,
#  'admarible': 306,
#  'macanally': 307,
#  'strutts': 308,
#  'churchill': 309,
#  'trotting': 310,
#  'fightm': 311,
#  'aussies': 312,
#  'pasa': 313,
#  'criminology': 314,
#  'marco': 315,
#  'nevada': 316,
#  'prescreening': 317,
#  'inebriation': 318,
#  'starringsean': 319,
#  'connecticute': 320,
#  'scorned': 321,
#  'mancori': 322,
#  'sensitivity': 323,
#  'anger': 324,
#  'decade': 325,
#  'spooky': 326,
#  'grieg': 327,
#  'dropping': 328,
#  'supposibly': 329,
#  'lavishly': 330,
#  'matriculates': 331,
#  'hadj': 332,
#  'raghubir': 333,
#  'alleging': 334,
#  'convincedness': 335,
#  'sedative': 336,
#  'whilhelm': 337,
#  'accessability': 338,
#  'tormento': 339,
#  'shroyer': 340,
#  'sillier': 341,
#  'orb': 342,
#  'katy': 343,
#  'koteas': 344,
#  'hellbound': 345,
#  'settlefor': 346,
#  'offhand': 347,
#  'innumerable': 348,
#  'fascinatingly': 349,
#  'sharpshooter': 350,
#  'hentai': 351,
#  'dimmed': 352,
#  'continental': 353,
#  'vasectomies': 354,
#  'directorial': 355,
#  'your': 356,
#  'chess': 357,
#  'hautefeuille': 358,
#  'hatley': 359,
#  'netherlands': 360,
#  'oland': 361,
#  'bell': 362,
#  'blakes': 363,
#  'fathoming': 364,
#  'padm': 365,
#  'environs': 366,
#  'monopolies': 367,
#  'guillaumme': 368,
#  'draza': 369,
#  'quasirealistic': 370,
#  'electricity': 371,
#  'unjust': 372,
#  'checkpoints': 373,
#  'boricua': 374,
#  'talia': 375,
#  'conditioning': 376,
#  'anupamji': 377,
#  'consecutive': 378,
#  'broker': 379,
#  'dantesque': 380,
#  'unaccomplished': 381,
#  'eisenmann': 382,
#  'undead': 383,
#  'pasqal': 384,
#  'pascow': 385,
#  'schlettow': 386,
#  'narration': 387,
#  'bedfellows': 388,
#  'differential': 389,
#  'habituation': 390,
#  'collective': 391,
#  'roubaix': 392,
#  'efenstor': 393,
#  'springing': 394,
#  'lebrock': 395,
#  'cheswick': 396,
#  'grinding': 397,
#  'chortle': 398,
#  'delightful': 399,
#  'terry': 400,
#  'ozkan': 401,
#  'watershed': 402,
#  'liqueur': 403,
#  'dekhiye': 404,
#  'favoritism': 405,
#  'mobocracy': 406,
#  'eccelston': 407,
#  'hallelujah': 408,
#  'joxs': 409,
#  'booke': 410,
#  'euthenased': 411,
#  'asphalt': 412,
#  'argentina': 413,
#  'bureacracy': 414,
#  'railroads': 415,
#  'merlet': 416,
#  'showcased': 417,
#  'diary': 418,
#  'sympathized': 419,
#  'chiani': 420,
#  'rug': 421,
#  'paint': 422,
#  'contributers': 423,
#  'readiness': 424,
#  'recieves': 425,
#  'pursuing': 426,
#  'radiating': 427,
#  'dramatizing': 428,
#  'sods': 429,
#  'gundam': 430,
#  'masterpeice': 431,
#  'uhs': 432,
#  'storied': 433,
#  'thc': 434,
#  'ripping': 435,
#  'oops': 436,
#  'zorba': 437,
#  'gaga': 438,
#  'nappy': 439,
#  'holey': 440,
#  'pooling': 441,
#  'stumped': 442,
#  'hotly': 443,
#  'doodo': 444,
#  'chonopolisians': 445,
#  'littlefield': 446,
#  'edition': 447,
#  'cardboard': 448,
#  'ebay': 449,
#  'donnacha': 450,
#  'unaccpectable': 451,
#  'fluke': 452,
#  'neutering': 453,
#  'eeks': 454,
#  'evocatively': 455,
#  'culinary': 456,
#  'duuum': 457,
#  'adherents': 458,
#  'jimi': 459,
#  'cliques': 460,
#  'overstyling': 461,
#  'radiohead': 462,
#  'formulatic': 463,
#  'shock': 464,
#  'hammish': 465,
#  'sunnydale': 466,
#  'fortunate': 467,
#  'kayak': 468,
#  'unwarily': 469,
#  'hypothermia': 470,
#  'validity': 471,
#  'confusion': 472,
#  'nope': 473,
#  'bedtime': 474,
#  'rustle': 475,
#  'rambunctious': 476,
#  'inexcusably': 477,
#  'sprinkled': 478,
#  'matt': 479,
#  'latecomer': 480,
#  'fratboy': 481,
#  'circumcision': 482,
#  'shampoo': 483,
#  'tempo': 484,
#  'calleia': 485,
#  'boars': 486,
#  'wresting': 487,
#  'rakastin': 488,
#  'marafon': 489,
#  'harrisonfirst': 490,
#  'shoddiest': 491,
#  'mall': 492,
#  'utility': 493,
#  'chinatown': 494,
#  'vileness': 495,
#  'recriminations': 496,
#  'solidity': 497,
#  'tersteeghe': 498,
#  'liquefied': 499,
#  'incentive': 500,
#  'sorts': 501,
#  'meandering': 502,
#  'shibasaki': 503,
#  'tusk': 504,
#  'duddy': 505,
#  'bewilder': 506,
#  'lubricated': 507,
#  'gear': 508,
#  'snoopy': 509,
#  'fight': 510,
#  'inexplicable': 511,
#  'tazmanian': 512,
#  'redstacey': 513,
#  'alyce': 514,
#  'seger': 515,
#  'douce': 516,
#  'dancehall': 517,
#  'devil': 518,
#  'flair': 519,
#  'misfortune': 520,
#  'myeres': 521,
#  'gitai': 522,
#  'maze': 523,
#  'inconsistancies': 524,
#  'citta': 525,
#  'identical': 526,
#  'durable': 527,
#  'vaxham': 528,
#  'anglo': 529,
#  'bragging': 530,
#  'giegud': 531,
#  'flirting': 532,
#  'mesquida': 533,
#  'dip': 534,
#  'crowell': 535,
#  'noway': 536,
#  'odin': 537,
#  'daslow': 538,
#  'emitting': 539,
#  'stoppage': 540,
#  'hedged': 541,
#  'antartic': 542,
#  'lasciviousness': 543,
#  'persecution': 544,
#  'fanshawe': 545,
#  'strobing': 546,
#  'heatbreaking': 547,
#  'menace': 548,
#  'phobias': 549,
#  'hool': 550,
#  'gad': 551,
#  'mutterings': 552,
#  'poet': 553,
#  'inconsistencies': 554,
#  'nallae': 555,
#  'ratings': 556,
#  'gould': 557,
#  'thata': 558,
#  'anecdote': 559,
#  'rail': 560,
#  'depardeu': 561,
#  'rungs': 562,
#  'capulet': 563,
#  'explorer': 564,
#  'seascape': 565,
#  'employee': 566,
#  'twentysomething': 567,
#  'renal': 568,
#  'windup': 569,
#  'shellshocked': 570,
#  'clinkers': 571,
#  'diatribe': 572,
#  'cloned': 573,
#  'meatlocker': 574,
#  'auditorium': 575,
#  'revitalizes': 576,
#  'gaylord': 577,
#  'coutard': 578,
#  'bones': 579,
#  'banderas': 580,
#  'births': 581,
#  'fosse': 582,
#  'sunroof': 583,
#  'blush': 584,
#  'gordon': 585,
#  'chagrin': 586,
#  'ghostbuster': 587,
#  'celebrations': 588,
#  'fetuccini': 589,
#  'planetary': 590,
#  'rifted': 591,
#  'long': 592,
#  'scholastic': 593,
#  'adversities': 594,
#  'equidor': 595,
#  'neglect': 596,
#  'dastak': 597,
#  'gojn': 598,
#  'hires': 599,
#  'airing': 600,
#  'bunny': 601,
#  'unbelievable': 602,
#  'lang': 603,
#  'mohawk': 604,
#  'purr': 605,
#  'termites': 606,
#  'often': 607,
#  'pliant': 608,
#  'firguring': 609,
#  'evaporated': 610,
#  'fawn': 611,
#  'creepies': 612,
#  'pollinating': 613,
#  'berzier': 614,
#  'suffice': 615,
#  'manchus': 616,
#  'baltic': 617,
#  'mutinous': 618,
#  'landmines': 619,
#  'knows': 620,
#  'alekos': 621,
#  'addressing': 622,
#  'dvr': 623,
#  'matteo': 624,
#  'behold': 625,
#  'hypnosis': 626,
#  'herbie': 627,
#  'pain': 628,
#  'keanu': 629,
#  'virulently': 630,
#  'dishwater': 631,
#  'moxy': 632,
#  'dinky': 633,
#  'plywood': 634,
#  'spawned': 635,
#  'bewafaa': 636,
#  'foothold': 637,
#  'indiains': 638,
#  'elivates': 639,
#  'micheals': 640,
#  'battre': 641,
#  'gregarious': 642,
#  'yar': 643,
#  'aerodynamics': 644,
#  'nonchalant': 645,
#  'appear': 646,
#  'favreau': 647,
#  'manon': 648,
#  'waves': 649,
#  'tuvoks': 650,
#  'sensuous': 651,
#  'howes': 652,
#  'ververgaert': 653,
#  'changeling': 654,
#  'stinking': 655,
#  'humanity': 656,
#  'grapes': 657,
#  'journos': 658,
#  'beautifully': 659,
#  'reunion': 660,
#  'vocational': 661,
#  'deploys': 662,
#  'americana': 663,
#  'infighting': 664,
#  'shakesphere': 665,
#  'coupledom': 666,
#  'objectively': 667,
#  'acharya': 668,
#  'kidnapper': 669,
#  'straighten': 670,
#  'streep': 671,
#  'queries': 672,
#  'theat': 673,
#  'thirsty': 674,
#  'computeranimation': 675,
#  'textural': 676,
#  'coonskin': 677,
#  'trio': 678,
#  'scouted': 679,
#  'referendum': 680,
#  'cuticle': 681,
#  'paperwork': 682,
#  'forewarns': 683,
#  'alchoholic': 684,
#  'tyrants': 685,
#  'saucy': 686,
#  'mallrats': 687,
#  'zigfield': 688,
#  'jeanane': 689,
#  'thinking': 690,
#  'realized': 691,
#  'conran': 692,
#  'semple': 693,
#  'masculin': 694,
#  'dramatize': 695,
#  'meddlesome': 696,
#  'appreciative': 697,
#  'kabaree': 698,
#  'constitutionally': 699,
#  'bookman': 700,
#  'hystericalness': 701,
#  'gospel': 702,
#  'heinkel': 703,
#  'tomcat': 704,
#  'klugman': 705,
#  'gymnast': 706,
#  'wilco': 707,
#  'waterstone': 708,
#  'ooohhh': 709,
#  'realityshowlike': 710,
#  'plugs': 711,
#  'bickering': 712,
#  'drudge': 713,
#  'demands': 714,
#  'perplexities': 715,
#  'dumbs': 716,
#  'nomadic': 717,
#  'slickers': 718,
#  'suleiman': 719,
#  'susi': 720,
#  'moshpit': 721,
#  'jitters': 722,
#  'sickness': 723,
#  'wazoo': 724,
#  'norse': 725,
#  'shillings': 726,
#  'montazuma': 727,
#  'shaloub': 728,
#  'gretel': 729,
#  'expanding': 730,
#  'majors': 731,
#  'outdated': 732,
#  'coool': 733,
#  'repellent': 734,
#  'starlet': 735,
#  'broader': 736,
#  'rockies': 737,
#  'kernel': 738,
#  'initial': 739,
#  'earths': 740,
#  'eschelons': 741,
#  'rebe': 742,
#  'jungle': 743,
#  'creasey': 744,
#  'bigg': 745,
#  'encapsulated': 746,
#  'deadbeat': 747,
#  'bangster': 748,
#  'wounds': 749,
#  'fixation': 750,
#  'password': 751,
#  'alicianne': 752,
#  'cccc': 753,
#  'ranches': 754,
#  'handless': 755,
#  'nosedive': 756,
#  'kearn': 757,
#  'samwise': 758,
#  'montmirail': 759,
#  'unachieving': 760,
#  'depriving': 761,
#  'disrobes': 762,
#  'smooshed': 763,
#  'molemen': 764,
#  'chessy': 765,
#  'anyhows': 766,
#  'flourishing': 767,
#  'iciness': 768,
#  'referat': 769,
#  'gruff': 770,
#  'argufying': 771,
#  'anno': 772,
#  'stows': 773,
#  'pados': 774,
#  'weaponry': 775,
#  'harvester': 776,
#  'modifies': 777,
#  'smelly': 778,
#  'unseemly': 779,
#  'cheddar': 780,
#  'overfed': 781,
#  'erupts': 782,
#  'fairly': 783,
#  'algrant': 784,
#  'jiggle': 785,
#  'shriver': 786,
#  'caution': 787,
#  'lanka': 788,
#  'darius': 789,
#  'nettie': 790,
#  'invesment': 791,
#  'also': 792,
#  'harf': 793,
#  'conscientious': 794,
#  'mysteries': 795,
#  'cheapen': 796,
#  'bergin': 797,
#  'reservedly': 798,
#  'hellishly': 799,
#  'slashing': 800,
#  'crasser': 801,
#  'handwriting': 802,
#  'unidentified': 803,
#  'advani': 804,
#  'ethnographer': 805,
#  'pontificating': 806,
#  'authentically': 807,
#  'faithless': 808,
#  'specials': 809,
#  'pakeza': 810,
#  'womanizer': 811,
#  'comin': 812,
#  'rove': 813,
#  'cr': 814,
#  'piggys': 815,
#  'excempt': 816,
#  'scarecrows': 817,
#  'opacity': 818,
#  'umpire': 819,
#  'interspersed': 820,
#  'pitifully': 821,
#  'mcshane': 822,
#  'stiffing': 823,
#  'hickenlooper': 824,
#  'facing': 825,
#  'boxed': 826,
#  'undercuts': 827,
#  'sweary': 828,
#  'flinstones': 829,
#  'stunners': 830,
#  'aggressors': 831,
#  'fracas': 832,
#  'aleisa': 833,
#  'blasters': 834,
#  'haev': 835,
#  'fluid': 836,
#  'beggers': 837,
#  'verisimilitude': 838,
#  'unacted': 839,
#  'numbing': 840,
#  'efff': 841,
#  'cadillacs': 842,
#  'geli': 843,
#  'diseased': 844,
#  'sully': 845,
#  'bouquet': 846,
#  'diffring': 847,
#  'bci': 848,
#  'martians': 849,
#  'overpower': 850,
#  'dekhne': 851,
#  'extramural': 852,
#  'naturelle': 853,
#  'tati': 854,
#  'flowerchild': 855,
#  'contradictory': 856,
#  'tumbuan': 857,
#  'vicious': 858,
#  'feij': 859,
#  'nb': 860,
#  'burgade': 861,
#  'propoghanda': 862,
#  'colonial': 863,
#  'dimming': 864,
#  'testy': 865,
#  'arcaica': 866,
#  'moneyshot': 867,
#  'sexuals': 868,
#  'detmers': 869,
#  'drss': 870,
#  'hormones': 871,
#  'incapacitates': 872,
#  'abuses': 873,
#  'patrizia': 874,
#  'ps': 875,
#  'flaring': 876,
#  'companions': 877,
#  'fowzi': 878,
#  'neccessarily': 879,
#  'cdn': 880,
#  'maths': 881,
#  'styalised': 882,
#  'esoterically': 883,
#  'steroids': 884,
#  'ruphert': 885,
#  'lodi': 886,
#  'karaca': 887,
#  'campier': 888,
#  'antics': 889,
#  'renaldo': 890,
#  'dermot': 891,
#  'areakt': 892,
#  'cooke': 893,
#  'digitised': 894,
#  'shola': 895,
#  'elbowroom': 896,
#  'squelched': 897,
#  'iliad': 898,
#  'safest': 899,
#  'szwarc': 900,
#  'puuurfect': 901,
#  'pulchritudinous': 902,
#  'mattei': 903,
#  'troubled': 904,
#  'ringer': 905,
#  'iowa': 906,
#  'debased': 907,
#  'breen': 908,
#  'rasuk': 909,
#  'shrewd': 910,
#  'idea': 911,
#  'onomatopoeic': 912,
#  'gleeson': 913,
#  'study': 914,
#  'neck': 915,
#  'personifies': 916,
#  'mirrored': 917,
#  'deft': 918,
#  'love': 919,
#  'searches': 920,
#  'ontario': 921,
#  'zombied': 922,
#  'maoris': 923,
#  'ransohoff': 924,
#  'cacophony': 925,
#  'charmer': 926,
#  'unsentimentally': 927,
#  'waldau': 928,
#  'craig': 929,
#  'vainly': 930,
#  'sonzero': 931,
#  'uncooperative': 932,
#  'zanta': 933,
#  'seachange': 934,
#  'destino': 935,
#  'rubinek': 936,
#  'uchovsky': 937,
#  'marino': 938,
#  'clunkier': 939,
#  'mcvay': 940,
#  'artagnan': 941,
#  'reason': 942,
#  'sleazefest': 943,
#  'belknap': 944,
#  'harassing': 945,
#  'dante': 946,
#  'tapped': 947,
#  'shihito': 948,
#  'cuckold': 949,
#  'yokozuna': 950,
#  'sherrys': 951,
#  'waxworks': 952,
#  'despicableness': 953,
#  'fending': 954,
#  'anual': 955,
#  'michelle': 956,
#  'jaid': 957,
#  'untraced': 958,
#  'techno': 959,
#  'mesmerising': 960,
#  'considerations': 961,
#  'extremis': 962,
#  'bulgakov': 963,
#  'unfolds': 964,
#  'okada': 965,
#  'delarue': 966,
#  'kindest': 967,
#  'defenceless': 968,
#  'gimme': 969,
#  'sttos': 970,
#  'jez': 971,
#  'larrazabal': 972,
#  'wiring': 973,
#  'operational': 974,
#  'etherything': 975,
#  'encompassed': 976,
#  'hwy': 977,
#  'jock': 978,
#  'ryder': 979,
#  'sparkles': 980,
#  'has': 981,
#  'lost': 982,
#  'spell': 983,
#  'immediately': 984,
#  'overseer': 985,
#  'bucsemi': 986,
#  'djs': 987,
#  'alongwith': 988,
#  'gesturing': 989,
#  'mochcinno': 990,
#  'reso': 991,
#  'toliet': 992,
#  'erroneous': 993,
#  'kristevian': 994,
#  'ji': 995,
#  'defectives': 996,
#  'neecessary': 997,
#  'contortions': 998,
#  'lords': 999,
#  ...}

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()
# Out:
# [('.', 27),
#  ('', 18),
#  ('the', 9),
#  ('to', 6),
#  ('high', 5),
#  ('i', 5),
#  ('bromwell', 4),
#  ('is', 4),
#  ('a', 4),
#  ('teachers', 4),
#  ('that', 4),
#  ('of', 4),
#  ('it', 2),
#  ('at', 2),
#  ('as', 2),
#  ('school', 2),
#  ('my', 2),
#  ('in', 2),
#  ('me', 2),
#  ('students', 2),
#  ('their', 2),
#  ('student', 2),
#  ('cartoon', 1),
#  ('comedy', 1),
#  ('ran', 1),
#  ('same', 1),
#  ('time', 1),
#  ('some', 1),
#  ('other', 1),
#  ('programs', 1),
#  ('about', 1),
#  ('life', 1),
#  ('such', 1),
#  ('years', 1),
#  ('teaching', 1),
#  ('profession', 1),
#  ('lead', 1),
#  ('believe', 1),
#  ('s', 1),
#  ('satire', 1),
#  ('much', 1),
#  ('closer', 1),
#  ('reality', 1),
#  ('than', 1),
#  ('scramble', 1),
#  ('survive', 1),
#  ('financially', 1),
#  ('insightful', 1),
#  ('who', 1),
#  ('can', 1),
#  ('see', 1),
#  ('right', 1),
#  ('through', 1),
#  ('pathetic', 1),
#  ('pomp', 1),
#  ('pettiness', 1),
#  ('whole', 1),
#  ('situation', 1),
#  ('all', 1),
#  ('remind', 1),
#  ('schools', 1),
#  ('knew', 1),
#  ('and', 1),
#  ('when', 1),
#  ('saw', 1),
#  ('episode', 1),
#  ('which', 1),
#  ('repeatedly', 1),
#  ('tried', 1),
#  ('burn', 1),
#  ('down', 1),
#  ('immediately', 1),
#  ('recalled', 1),
#  ('classic', 1),
#  ('line', 1),
#  ('inspector', 1),
#  ('m', 1),
#  ('here', 1),
#  ('sack', 1),
#  ('one', 1),
#  ('your', 1),
#  ('welcome', 1),
#  ('expect', 1),
#  ('many', 1),
#  ('adults', 1),
#  ('age', 1),
#  ('think', 1),
#  ('far', 1),
#  ('fetched', 1),
#  ('what', 1),
#  ('pity', 1),
#  ('isn', 1),
#  ('t', 1)]

# %% [markdown]
# # 项目 4：减小输入数据的噪声<a id='project_4'></a>
#
# **待办：** 学习 Andrew 上一个视频的操作，尝试为输入数据减小噪声，具体操作内容如下：
# * 将你之前创建的类 `SentimentNetwork` 复制到下方的代码框中。
# * 修改 `update_input_layer`，使其不再统计各单词出现的次数，而只记录单词是否出现过。

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video 

import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        # TODO: populate review_vocab with all of the words in the given reviews 
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
        # Convert the vocabulary set to a list so we can access words via indices 
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        for label in labels:
            label_vocab.add(label)
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook 

        for i,word in enumerate(self.review_vocab):
            self.word2index[word] = i
            
        # Create a dictionary of labels mapped to index positions 
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead 
        for j,label in enumerate(self.label_vocab):
            self.label2index[label] = j
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes, self.hidden_nodes))
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero 1 x input_nodes，
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"

        # clear out previous state by resetting the layer to be all 0s
        self.layer_0 *= 0

        # TODO: count how many times each word is used in the given review and store the results in layer_0 
        for word in review.split(' '):

            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] = 1
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        if (label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures 
        return 1 / (1+np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        return output * (1-output)

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            #input layer
            self.update_input_layer(review)
            
            #hidden layer 输出
            layer_1 = self.layer_0.dot(self.weights_0_1)
            
            #output layer 输出
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            #  Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            # 由于此处是线性的，所以不用进行斜率调整
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            # Keep track of correct predictions.
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# 运行下方代码框，重建网络并对其进行训练。注意，此处重新采纳了较高的学习率，即 `0.1` 。

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):71.96 #Correct:1793 #Trained:2501 Training Accuracy:71.6%
# Progress:20.8% Speed(reviews/sec):71.15 #Correct:3766 #Trained:5001 Training Accuracy:75.3%
# Progress:31.2% Speed(reviews/sec):70.87 #Correct:5863 #Trained:7501 Training Accuracy:78.1%
# Progress:41.6% Speed(reviews/sec):70.75 #Correct:8012 #Trained:10001 Training Accuracy:80.1%
# Progress:52.0% Speed(reviews/sec):70.49 #Correct:10127 #Trained:12501 Training Accuracy:81.0%
# Progress:62.5% Speed(reviews/sec):70.28 #Correct:12246 #Trained:15001 Training Accuracy:81.6%
# Progress:72.9% Speed(reviews/sec):70.27 #Correct:14370 #Trained:17501 Training Accuracy:82.1%
# Progress:83.3% Speed(reviews/sec):70.32 #Correct:16558 #Trained:20001 Training Accuracy:82.7%
# Progress:93.7% Speed(reviews/sec):70.46 #Correct:18748 #Trained:22501 Training Accuracy:83.3%
# Progress:99.9% Speed(reviews/sec):70.37 #Correct:20068 #Trained:24000 Training Accuracy:83.6%

# %% [markdown]
# 这次的训练效果应该比之前的好多了，虽然还不够完美，但进步很大。运行下方代码框，用那一千条预测对模型进行测试。

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):482.0 #Correct:797 #Tested:1000 Testing Accuracy:79.7%

# %% [markdown]
# # 项目 4 到此结束。
# ## 实际上 Andrew 关于本项目的解决方案已在上一个视频中有所提及，如果你对那个项目还有问题，请重看视频，然后继续学习下一课。
#
# # 下方代码框包含 Andrew 在下一个视频中使用的代码，因此你无须手动输入，只需运行代码框，即可跟着视频运行代码。

# %%
Image(filename='sentiment_network_sparse.png')
# Out:
# -----------------------------------------------------------------
# NameError                       Traceback (most recent call last)
# <ipython-input-1-dd288d9ab3a7> in <module>
# ----> 1 Image(filename='sentiment_network_sparse.png')
#
# NameError: name 'Image' is not defined

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # 项目 5：提高网络效率<a id='project_5'></a>
# **待办：** 删除前向传播和反向传播造成的冗余相乘和相加，从而提高类 `SentimentNetwork` 的效率，为此，可进行如下操作：
# * 将上一个项目的类 `SentimentNetwork` 复制到下方代码框中。
# * 删除函数 `update_input_layer`——本版本不需要该函数。
# * 修改 `init_network`；
# >* 因为你已经不需要单独的输入层了，所以删除任何与 `self.layer_0` 有关的内容
# >* 因为你要更直接地处理之前的隐藏层，所以要创建一个二维矩阵 `self.layer_1`，使其形状为 1 x hidden_nodes，并将其所有值初始化为 0。
# * 修改 `train`：
# >* 将输入参数名从 `training_reviews` 改为 `training_reviews_raw`，为下一步做好准备。
# >* 你需要在函数开头部分对评论进行预处理，将其转换成一张索引列表，其中的索引（源自 `word2index` ）是在评论中真正出现过的，这与 Andrew 在视频中将具体索引设为 1 的操作有异曲同工之妙。你应该用代码创建一个局部的`列表`变量 `training_reviews`，对于 `training_reviews_raw` 中的 每一条评论，该变量都会建立一个与之相关的列表，而这些列表应包含在评论里出现过的单词的索引。
# >* 取消对函数 `update_input_layer` 的调用。
# >* 在前向传播部分，将更新 `layer_1` 的代码替换为新的逻辑代码，只为在评论里出现过的索引添加权重。
# >* 更新 `weights_0_1` 时，只更新用于前向传播的各权重。
# * 修改 `run`；
# >* 取消对函数 `update_input_layer` 的调用。
# >* 使用 `self` 的 `layer_1` 而非局部的 `layer_1` 对象。
# >* 和修改 `train` 一样，你需要对 `评论` 进行预处理，以便利用单词索引，然后给在评论中出现过的索引增加权重，从而对 `layer_1` 进行更新。

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# 运行下方代码框，再次重建网络并对网络进行训练。

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# 训练效果应该比之前的要好得多了。运行下方代码框，用那一千条预测来测试你的模型。

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # 项目 5 到此结束。
# ## 请进入下一个视频，观看  Andrew 的解决方案，然后继续学习下一课。
# # 进一步降噪<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # 项目 6：有策略地删减词汇，进行降噪<a id='project_6'></a>
#
# **待办：** 进一步减小词汇表的噪声，以便提高 `SentimentNetwork` 的性能，具体操作如下：
# * 将在之前项目里创建的类 `SentimentNetwork` 复制到下方代码框中。
# * 修改  `pre_process_data`；
# >* 新增两个参数：`min_count` 和 `polarity_cutoff`
# >* 计算在评论中出现的单词的正面评价/负面评价比。（你可以利用在 notebook 其它地方写下的代码，但跟之前那些辅助代码一样，我们要把代码放到本类中。）
# >* Andrew 的解决方案只计算了出现次数不少于 50 次的单词的正面评价/负面评价比，这样能防止网络赋予罕见单词太多的感情色彩，如果你喜欢，也可以在你的解决方案里添加这一步。
# >* 修改本函数，使单词只有在词汇表中出现次数大于 `min_count` 时才得以添加到词汇表中。
# >* 修改本函数，使单词只有在正面评价/负面评价比的绝对值不小于 `polarity_cutoff`时 才得以添加到词汇表中。
# * 修改 `__init__`：
# >* 还是新增那两个参数 (`min_count` 和 `polarity_cutoff`) 并在调用 `pre_process_data` 时使用它们。

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# 运行下方代码框，用较小的 polarity cutoff 参数值来训练网络。

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# 运行下方代码框以测试网络性能，结果应为

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# 运行下方代码框，用大许多的 polarity cutoff 参数值来训练网络。

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# 运行下方代码框，测试网络性能。

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # 项目 6 到此结束。
# ## 请进入下一个视频， 观看 Andrew 的解决方案，然后继续学习下一课。
#
# # 分析：权重怎么了？<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
